# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading and Merging

# %%
df = pd.read_csv('./data/partidos.csv')
df_ranking = pd.read_csv('./data/ranking_fifa.csv')
df_transfermarkt = pd.read_csv('./data/transfermarkt.csv')
# Out:
# /var/folders/c9/88zz0bpj7wx6d38dghnlklqh0000gn/T/ipykernel_79077/1432938540.py:1: DtypeWarning: Columns (42,43,44,45,46,47,54,55,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,564,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,598,599,600,601,602,603,604,605,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,621,622,623,624,625,626,627,628,629,630,631,632,633,634,635,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,662,663,664,665,666,667,668,669,670,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,719,720,721,722,723,724,725,726,727,728,729,730,731,732,733,734,735,736,737,738,739,740,741,742,743,744,745,746,747,748,749,750,751,752,753,754,755,756,757,758,759,760,761,762,763,764,765,766,767,768,769,770,771,772,773,774,775,776,777,778,779,780,781,782,783,784,785,786,787,788,789,790,791,792,793,794,795,796,797,798,799,800,801,802,803,804,805,806,807,808,809,810,811,812,813,814,815,816,817,818,819,820,821,822,823,824,825,826,827,828,829,830,831,832,833,834,835,836,837,838,839,840,841,842,843,844,845,846,847,848,849,850,851,852,853,854,855,856,857,858,859,860,861,862,863,864,865,866,867,868,869,870,871,872,873,874,875,876,877,878,879,880,881,882,883,884,885,886,887,888,889,890,891,892,893,894,895,896,897,898,899,900,901,902,903,904,905,906,907,908,909,910,911,912,913,914,915,916,917,918,919,920,921,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,973,974,975,976,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041 ...
#   df = pd.read_csv('./data/partidos.csv')

# %%
# first we changed to english our original variables that were in spanish
rename_data_matches = {
    'Fecha': 'Date',
    'Equipo_Local': 'Home_Team',
    'Equipo_Visitante': 'Away_Team',
    'Resultado': 'Result',
    'Goles_esperados_(xG)_Local': 'Expected_Goals_Home_(xG)',
    'Goles_esperados_(xG)_Visitante': 'Expected_Goals_Away_(xG)',
    'Posesión_Local': 'Possession_Home',
    'Posesión_Visitante': 'Possession_Away',
    'Remates_totales_Local': 'Total_Shots_Home',
    'Remates_totales_Visitante': 'Total_Shots_Away',
    'Remates_a_puerta_Local': 'Shots_on_Target_Home',
    'Remates_a_puerta_Visitante': 'Shots_on_Target_Away',
    'Remates_fuera_Local': 'Shots_Off_Target_Home',
    'Remates_fuera_Visitante': 'Shots_Off_Target_Away',
    'Remates_rechazados_Local': 'Blocked_Shots_Home',
    'Remates_rechazados_Visitante': 'Blocked_Shots_Away',
    'Córneres_Local': 'Corners_Home',
    'Córneres_Visitante': 'Corners_Away',
    'Pases_Local': 'Passes_Home',
    'Pases_Visitante': 'Passes_Away',
    'Tarjetas_amarillas_Local': 'Yellow_Cards_Home',
    'Tarjetas_amarillas_Visitante': 'Yellow_Cards_Away',
    'Fueras_de_juego_Local': 'Offsides_Home',
    'Fueras_de_juego_Visitante': 'Offsides_Away',
    'Tiros_libres_Local': 'Free_Kicks_Home',
    'Tiros_libres_Visitante': 'Free_Kicks_Away',
    'Saques_de_banda_Local': 'Throw_Ins_Home',
    'Saques_de_banda_Visitante': 'Throw_Ins_Away',
    'Faltas_Local': 'Fouls_Home',
    'Faltas_Visitante': 'Fouls_Away',
    'Paradas_Local': 'Saves_Home',
    'Paradas_Visitante': 'Saves_Away',
    'Anuncio_Local': 'Announcement_Home',
    'Anuncio_Visitante': 'Announcement_Away',
    'checkbox_label_label_Local': 'Checkbox_Label_Home',
    'checkbox_label_label_Visitante': 'Checkbox_Label_Away',
}

rename_ranking = {
    'País': 'Country',
    'Puntuación': 'Score',
    'Fecha': 'Date',
}

rename_transfermarkt = {
    'Equipo': 'Team',
    'Valor_Mercado_Millones_Eur': 'Market_Value_Millions_EUR',
}

df.rename(columns=rename_data_matches, inplace=True)
df_ranking.rename(columns=rename_ranking, inplace=True)
df_transfermarkt.rename(columns=rename_transfermarkt, inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'URL', 'Home_Team', 'Away_Team', 'Result',
#        'Expected_Goals_Home_(xG)', 'Expected_Goals_Away_(xG)',
#        'Possession_Home', 'Possession_Away',
#        ...
#        '84%(410/486)Pases79%(328/417)_Local',
#        '84%(410/486)Pases79%(328/417)_Visitante', '5Faltas11_Local',
#        '5Faltas11_Visitante', '73%(263/360)Pases74%(264/359)_Local',
#        '73%(263/360)Pases74%(264/359)_Visitante',
#        '82%(347/422)Pases86%(431/501)_Local',
#        '82%(347/422)Pases86%(431/501)_Visitante',
#        '68%(282/413)Pases58%(180/308)_Local',
#        '68%(282/413)Pases58%(180/308)_Visitante'],
#       dtype='object', length=2778)

# %%
# check no duplicates
print(df.shape)
df.drop_duplicates(subset=['URL', 'Date', 'Home_Team', 'Away_Team'], keep='last', inplace=True)
print(df.shape)
# Out:
# (3316, 2778)
# (3316, 2778)

# %% [markdown]
# ## Dataset Overview
#
# Summary of the raw dataset after deduplication: shape, variable type and temporal coverage.

# %%
# Table 1: Raw dataset summary 
print(f'Shape: {df.shape[0]} matches x {df.shape[1]} variables')
print(f'Temporal range: {df["Date"].min()} - {df["Date"].max()}')

tipos = df.dtypes.value_counts()
print('\nTable 1. Variable types in raw dataset')
for t, n in tipos.items():
    print(f'  {str(t):15s}: {n} columns')

print(f'\nTotal missing values: {df.isna().sum().sum():,}')
print(f'Overall missing rate: {df.isna().mean().mean():.1%}')
# Out:
# Shape: 3316 matches x 2778 variables
# Temporal range: 01.01.2026 14:00 - 31.12.2025 20:00
#
# Table 1. Variable types in raw dataset
#   object         : 2720 columns
#   float64        : 57 columns
#   int64          : 1 columns
#
# Total missing values: 9,090,640
# Overall missing rate: 98.7%

# %% [markdown]
# ### All Matches
#
# For the new research question (*Which performance statistics predict the match outcome?*), we keep all available matches without filtering by World Cup teams.

# %%
print(df.shape)
# Out:
# (3316, 2778)

# %% [markdown]
# ## Join ranking FIFA

# %% [markdown]
# We will create a dictionary to join the FlashScore data with the FIFA ranking.

# %%
# KEY = Name in df_ranking (the one we want to change)
# VALUE = Name in df_partidos (the one we want to keep)
# Country names are kept in Spanish on purpose because these are raw values from the sources and changing them would break the join.
country_name_mapping = {
    'EEUU': 'EE. UU.',
    'RI de Irán': 'Irán',
    'República de Corea': 'Corea del Sur',
    'RD del Congo': 'RD Congo',
    'Bosnia y Herzegovina': 'Bosnia-Herzegovina',
    'Baréin': 'Bahréin',
    'RP China': 'China',
    'República Kirguisa': 'Kirguistán',
    'Kazajstán': 'Kazajistán',
    'RDP de Corea': 'Corea del Norte',
    'Guinea-Bissáu': 'Guinea-Bisáu',
    'San Cristóbal y Nieves': 'Saint Kitts y Nevis',
    'Hong Kong, China': 'Hong Kong',
    'Myanmar': 'Birmania',
    'Esuatini': 'Eswatini',
    'Chinese Taipei': 'China Taipei',
    'Bangladesh': 'Bangladés',
    'Samoa Estadounidense': 'Samoa Americana',
    'Brunéi Darussalam': 'Brunéi',
    'República de Irlanda': 'Irlanda',
    'Qatar': 'Catar',
    'Turcas y Caicos': 'Islas Turcas y Caicos',
    'Antigua y Barbuda': 'Antigua & Barbuda',
    'Comoras': 'Comores'
}

# Apply the replacement to the df_ranking column
df_ranking['Country'] = df_ranking['Country'].replace(country_name_mapping)

# Check if any country is unmatched
country_df = set(df['Home_Team'].unique()).union(set(df['Away_Team'].unique()))
country_ranking = set(df_ranking['Country'].unique())
orphan = country_df - country_ranking

if orphan:
    print(f"WARNING: {len(orphan)} countries have NO associated FIFA ranking:")
    print(sorted(list(orphan)))
else:
    print(" All countries in your matches have an exact match in the FIFA ranking.")
# Out:
# WARNING: 160 countries have NO associated FIFA ranking:
# ['Afganistán Sub-20', 'Albania Sub-21', 'Alemania Sub-17', 'Alemania Sub-18', 'Alemania Sub-19', 'Arabia Saudí Sub-20', 'Argelia Sub-20', 'Argelia Sub-23', 'Argentina Sub-17', 'Argentina Sub-20', 'Australia Sub-17', 'Australia Sub-20', 'Austria Sub-17', 'Austria Sub-18', 'Bonaire', 'Bosnia-Herzegovina Sub-19', 'Brasil Sub-20', 'Bulgaria Sub-19', 'Bután Sub-23', 'Bélgica Sub-17', 'Bélgica Sub-21', 'Catar Sub-17', 'Catar Sub-20', 'Catar Sub-23', 'Chile Sub-17', 'Chile Sub-20', 'China Sub-20', 'China Sub-23', 'Chipre Sub-19', 'Colombia Sub-20', 'Corea del Norte Sub-23', 'Corea del Sur Sub-17', 'Corea del Sur Sub-23', 'Costa Rica Sub-20', 'Costa de Marfil Sub-20', 'Costa de Marfil Sub-23', 'Croacia Sub-17', 'Croacia Sub-19', 'EE. UU. Sub-18', 'EE. UU. Sub-19', 'EE. UU. Sub-20', 'EE. UU. Sub-21', 'Ecuador Sub-17', 'Egipto Sub-19', 'Egipto Sub-20', 'Emiratos Árabes Unidos Sub-19', 'Emiratos Árabes Unidos Sub-20', 'Emiratos Árabes Unidos Sub-23', 'Escocia Sub-17', 'Eslovaquia Sub-18', 'Eslovaquia Sub-19', 'Eslovenia Sub-18', 'España Sub-17', 'España Sub-18', 'España Sub-19', 'Estonia Sub-17', 'Finlandia Sub-17', 'Fiyi Sub-19', 'Francia Sub-17', 'Gales Sub-19', 'Georgia Sub-17', 'Granada Sub-20', 'Grecia Sub-17', 'Grecia Sub-19', 'Grecia Sub-21', 'Guadalupe', 'Guayana Francesa', 'Hungría Sub-17', 'Hungría Sub-18', 'Hungría Sub-21', 'India Sub-17', 'India Sub-23', 'Inglaterra Sub-18', 'Inglaterra Sub-20', 'Irak Sub-19', 'Irak Sub-20', 'Irlanda Sub-17', 'Irlanda del Norte Sub-17', 'Islandia Sub-19', 'Islas Salomón Sub-19', 'Israel Sub-19', 'Israel Sub-21', 'Italia Sub-17', 'Italia Sub-18', 'Italia Sub-19', 'Italia Sub-20', 'Japón Sub-17', 'Japón Sub-19', 'Japón Sub-21', 'Japón Sub-23', 'Jordania Sub-20', 'Jordania Sub-23', 'Kirguistán Sub-20', 'Kirguistán Sub-23', 'Las Vegas Lights', 'Letonia Sub-19', 'Liechtenstein Sub-21', 'Luxemburgo Sub-17', 'Luxemburgo Sub-18', 'Macedonia del Norte Sub-17', 'Macedonia del Norte Sub-18', 'Macedonia del Norte Sub-19', 'Macedonia del Norte Sub-20', 'Maldivas Sub-20', 'Malta Sub-17', 'Marruecos Sub-18', 'Marruecos Sub-23', 'Martinica', 'Mauritania Sub-20', 'Moldavia Sub-17', 'Montenegro Sub-18', 'México Sub-20', 'Noruega Sub-17', 'Noruega Sub-19', 'Omán Sub-19', 'Omán Sub-23', 'PSG Sub-17', 'Paraguay Sub-20', 'Países Bajos Sub-17', 'Países Bajos Sub-21', 'Perú Sub-20', 'Polonia Sub-17', 'Portugal Sub-17', 'Portugal Sub-18', 'RD Congo Sub-23', 'Rangers Sub-17', 'República Checa Sub-17', 'República Checa Sub-19', 'República Dominicana Sub-23', 'Rusia Sub-21', 'Saint Martin', 'San Vicente y las Granadinas Sub-20', 'Serbia Sub-18', 'Serbia Sub-21', 'Singapur Sub-19', 'Singapur Sub-20', 'Sint Maarten', 'Suecia Sub-17', 'Suiza Sub-17', 'Tailandia Sub-23', 'Tayikistán Sub-20', 'Tayikistán Sub-23', 'Trinidad y Tobago Sub-20', 'Turkmenistán Sub-20', 'Turquía Sub-17', 'Turquía Sub-18', 'Turquía Sub-19', 'Túnez Sub-18', 'Túnez Sub-20', 'Túnez Sub-23', 'Ucrania Sub-17', 'Ucrania Sub-18', 'Urartu', 'Uruguay Sub-17', 'Uzbekistán Sub-18', 'Uzbekistán Sub-19', 'Uzbekistán Sub-20', 'Uzbekistán Sub-23', 'Vietnam Sub-23', 'Zambia Sub-23']

# %%
print(df_ranking.head())
# Out:
#       Country    Score        Date
# 0     Francia  1877.32  01-04-2026
# 1      España  1876.40  01-04-2026
# 2   Argentina  1874.81  01-04-2026
# 3  Inglaterra  1825.97  01-04-2026
# 4    Portugal  1763.83  01-04-2026

# %% [markdown]
# We unify the date formats for the JOIN.

# %%
# Date handling
# Convert the column to Pandas datetime format, recognising dots and time
df['Date'] = pd.to_datetime(df['Date'], format='%d.%m.%Y %H:%M')

# If the time is not needed, keep only the clean date (YYYY-MM-DD)
df['Date'] = df['Date'].dt.normalize()

# Change the date format to YYYY-MM-DD
df_ranking['Date'] = pd.to_datetime(df_ranking['Date'], format='%d-%m-%Y')
df_ranking['Date'] = pd.to_datetime(df_ranking['Date']).dt.strftime('%Y-%m-%d')

# Force both columns to pure datetime
df['Date'] = pd.to_datetime(df['Date']).dt.tz_localize(None)
df_ranking['Date'] = pd.to_datetime(df_ranking['Date']).dt.tz_localize(None)

# %%
# SORT by date (required for merge_asof)
df = df.sort_values('Date').reset_index(drop=True)
df_ranking = df_ranking.sort_values('Date').reset_index(drop=True)

# 1. Merge ranking for the HOME TEAM
df = pd.merge_asof(
    df, 
    df_ranking,
    on='Date',   
    left_by='Home_Team',   
    right_by='Country',          
    direction='backward',     
    allow_exact_matches=False 
)

df = df.rename(columns={
    'Score': 'Home_Score'  
})

# 2. Merge ranking for the AWAY TEAM
df = pd.merge_asof(
    df, 
    df_ranking,
    on='Date',       
    left_by='Away_Team',
    right_by='Country',
    direction='backward',
    allow_exact_matches=False 
) 

# Rename the away team data
df = df.rename(columns={
    'Score': 'Away_Score'
})

#  The Country column from df_ranking will appear twice, so we clean it up
columnas_a_borrar = [col for col in df.columns if 'Country' in col]
print(columnas_a_borrar)
df = df.drop(columns=columnas_a_borrar)

# Check the JOIN
print(df[['Date', 'Home_Team', 'Home_Score', 'Away_Team', 'Away_Score']].head())
# Out:
# ['Country_x', 'Country_y']
#         Date Home_Team  Home_Score  Away_Team  Away_Score
# 0 2019-06-06  Mongolia       915.0     Brunéi       903.0
# 1 2019-06-06     Macao       925.0  Sri Lanka       886.0
# 2 2019-06-06      Laos       923.0  Bangladés       907.0
# 3 2019-06-06   Camboya       970.0   Pakistán       888.0
# 4 2019-06-06     Bután       917.0       Guam       907.0

# %% [markdown]
# ## Join Market Value

# %%
df_transfermarkt.head()
# Out:
#          Team  Market_Value_Millions_EUR
# 0     Francia                      58.58
# 1  Inglaterra                      52.43
# 2      España                      47.03
# 3    Portugal                      38.67
# 4    Alemania                      36.42

# %%
dic_Transfermarkt = {
    'Estados Unidos': 'EE. UU.',
    'Chequia': 'República Checa',
    'República Democrática del Congo': 'RD Congo',
    'Arabia Saudita': 'Arabia Saudí',
    'Malí': 'Mali',
    'Comoras': 'Comores',
    'Baréin': 'Bahréin',
    'Myanmar': 'Birmania',
    'República del Congo': 'Congo',
    'China Taipéi': 'China Taipei',
    'Esuatini': 'Eswatini',
    'Antigua y Barbuda': 'Antigua & Barbuda',
    'San Cristóbal y Nieves': 'Saint Kitts y Nevis',
    'Brunéi Darussalam': 'Brunéi',
    'Islas Vírgenes de los Estados Unidos': 'Islas Vírgenes Estadounidenses'
}

df_transfermarkt['Team'] = df_transfermarkt['Team'].replace(dic_Transfermarkt)

# %%
# 1.Merge market value for the HOME TEAM
df = pd.merge(
    df, 
    df_transfermarkt,        
    left_on='Home_Team',   
    right_on='Team',       
    how='left'               
)

# Renaming the home value column and dropping the redundant Team column
df = df.rename(columns={
    'Market_Value_Millions_EUR': 'Home_Market_Value_Millions_EUR'  
}).drop(columns=['Team'])

# 2. Merge market value for the AWAY TEAM
df = pd.merge(
    df, 
    df_transfermarkt,        
    left_on='Away_Team', 
    right_on='Team',     
    how='left'
)

df = df.rename(columns={
    'Market_Value_Millions_EUR': 'Away_Market_Value_Millions_EUR'
}).drop(columns=['Team'])

# Check the JOIN
print(df[['Date', 'Home_Team', 'Home_Market_Value_Millions_EUR', 'Away_Team', 'Away_Market_Value_Millions_EUR']].head())
# Out:
#         Date Home_Team  Home_Market_Value_Millions_EUR  Away_Team  \
# 0 2019-06-06  Mongolia                           0.024     Brunéi
# 1 2019-06-06     Macao                           0.016  Sri Lanka
# 2 2019-06-06      Laos                           0.057  Bangladés
# 3 2019-06-06   Camboya                           0.099   Pakistán
# 4 2019-06-06     Bután                           0.037       Guam
#
#    Away_Market_Value_Millions_EUR
# 0                           0.035
# 1                           0.040
# 2                           0.315
# 3                           0.154
# 4                           0.010

# %% [markdown]
# # Data Cleaning

# %%
print(df.shape)
# we want rows that do NOT  contain 'sub' (to remove U20, U17, etc)
# we use na=False to avoid errors when a cell is empty
local_filter = ~df['Home_Team'].astype(str).str.contains('sub', case=False, na=False)
away_filter = ~df['Away_Team'].astype(str).str.contains('sub', case=False, na=False)

# both conditions together
df = df[local_filter & away_filter]

# reset index to be sequential after dropping rows
df = df.reset_index(drop=True)
print(df.shape)
df.head()
# Out:
# (3316, 2782)
# (3144, 2782)
#    Unnamed: 0       Date                                                URL  \
# 0        2542 2019-06-06  https://www.flashscore.es/partido/futbol/brune...
# 1        2541 2019-06-06  https://www.flashscore.es/partido/futbol/macao...
# 2        2540 2019-06-06  https://www.flashscore.es/partido/futbol/bangl...
# 3        2539 2019-06-06  https://www.flashscore.es/partido/futbol/cambo...
# 4        2538 2019-06-06  https://www.flashscore.es/partido/futbol/butan...
#
#   Home_Team  Away_Team         Result  Expected_Goals_Home_(xG)  \
# 0  Mongolia     Brunéi  2-0Finalizado                       NaN
# 1     Macao  Sri Lanka  1-0Finalizado                       NaN
# 2      Laos  Bangladés  0-1Finalizado                       NaN
# 3   Camboya   Pakistán  2-0Finalizado                       NaN
# 4     Bután       Guam  1-0Finalizado                       NaN
#
#    Expected_Goals_Away_(xG) Possession_Home Possession_Away  Total_Shots_Home  \
# 0                       NaN             NaN             NaN               NaN
# 1                       NaN             NaN             NaN               NaN
# 2                       NaN             NaN             NaN               NaN
# 3                       NaN             NaN             NaN               NaN
# 4                       NaN             NaN             NaN               NaN
#
#    Total_Shots_Away  Shots_on_Target_Home  Shots_on_Target_Away  \
# 0               NaN                   NaN                   NaN
# 1               NaN                   NaN                   NaN
# 2               NaN                   NaN                   NaN
# 3               NaN                   NaN                   NaN
# 4               NaN                   NaN                   NaN
#
#    Grandes_ocasiones_Local  Grandes_ocasiones_Visitante  Corners_Home  \
# 0                      NaN                          NaN           NaN
# 1                      NaN                          NaN           NaN
# 2                      NaN                          NaN           NaN
# 3                      NaN                          NaN           NaN
# 4                      NaN                          NaN           NaN
#
#    Corners_Away Passes_Home Passes_Away  Yellow_Cards_Home  Yellow_Cards_Away  \
# 0           NaN         NaN         NaN                NaN                NaN
# 1           NaN         NaN         NaN                NaN                NaN
# 2           NaN         NaN         NaN                NaN                NaN
# 3           NaN         NaN         NaN                NaN                NaN
# 4           NaN         NaN         NaN                NaN                NaN
#
#    xG_a_puerta_(xGOT)_Local  xG_a_puerta_(xGOT)_Visitante  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#    Shots_Off_Target_Home  Shots_Off_Target_Away  Blocked_Shots_Home  \
# 0                    NaN                    NaN                 NaN
# 1                    NaN                    NaN                 NaN
# 2                    NaN                    NaN                 NaN
# 3                    NaN                    NaN                 NaN
# 4                    NaN                    NaN                 NaN
#
#    Blocked_Shots_Away  Remates_dentro_del_área_Local  \
# 0                 NaN                            NaN
# 1                 NaN                            NaN
# 2                 NaN                            NaN
# 3                 NaN                            NaN
# 4                 NaN                            NaN
#
#    Remates_dentro_del_área_Visitante  Remates_fuera_del_área_Local  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    Remates_fuera_del_área_Visitante  Al_palo_Local  Al_palo_Visitante  \
# 0                               NaN            NaN                NaN
# 1                               NaN            NaN                NaN
# 2                               NaN            NaN                NaN
# 3                               NaN            NaN                NaN
# 4                               NaN            NaN                NaN
#
#    Goles_de_cabeza_Local  Goles_de_cabeza_Visitante  \
# 0                    NaN                        NaN
# 1                    NaN                        NaN
# 2                    NaN                        NaN
# 3                    NaN                        NaN
# 4                    NaN                        NaN
#
#    Toques_en_el_área_rival_Local  Toques_en_el_área_rival_Visitante  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
#
#    Offsides_Home  Offsides_Away  Free_Kicks_Home  Free_Kicks_Away  \
# 0            NaN            NaN              NaN              NaN
# 1            NaN            NaN              NaN              NaN
# 2            NaN            NaN              NaN              NaN
# 3            NaN            NaN              NaN              NaN
# 4            NaN            NaN              NaN              NaN
#
#   Pases_largos_Local Pases_largos_Visitante Pases_en_el_tercio_final_Local  \
# 0                NaN                    NaN                            NaN
# 1                NaN                    NaN                            NaN
# 2                NaN                    NaN                            NaN
# 3                NaN                    NaN                            NaN
# 4                NaN                    NaN                            NaN
#
#   Pases_en_el_tercio_final_Visitante Centros_Local Centros_Visitante  \
# 0                                NaN           NaN               NaN
# 1                                NaN           NaN               NaN
# 2                                NaN           NaN               NaN
# 3                                NaN           NaN               NaN
# 4                                NaN           NaN               NaN
#
#    Asistencias_esperadas_(xA)_Local  Asistencias_esperadas_(xA)_Visitante  \
# 0                               NaN                                   NaN
# 1                               NaN                                   NaN
# 2                               NaN                                   NaN
# 3                               NaN                                   NaN
# 4                               NaN                                   NaN
#
#    Throw_Ins_Home  Throw_Ins_Away  Fouls_Home  Fouls_Away Entradas_Local  \
# 0             NaN             NaN         NaN         NaN            NaN
# 1             NaN             NaN         NaN         NaN            NaN
# 2             NaN             NaN         NaN         NaN            NaN
# 3             NaN             NaN         NaN         NaN            NaN
# 4             NaN             NaN         NaN         NaN            NaN
#
#   Entradas_Visitante  Duelos_ganados_Local  Duelos_ganados_Visitante  \
# 0                NaN                   NaN                       NaN
# 1                NaN                   NaN                       NaN
# 2                NaN                   NaN                       NaN
# 3                NaN                   NaN                       NaN
# 4                NaN                   NaN                       NaN
#
#    Despejes_Local  Despejes_Visitante  Intercepciones_Local  \
# 0             NaN                 NaN                   NaN
# 1             NaN                 NaN                   NaN
# 2             NaN                 NaN                   NaN
# 3             NaN                 NaN                   NaN
# 4             NaN                 NaN                   NaN
#
#    Intercepciones_Visitante  Errores_conducentes_a_remate_Local  \
# 0                       NaN                                 NaN
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       NaN                                 NaN
# 4                       NaN                                 NaN
#
#    Errores_conducentes_a_remate_Visitante  Errores_conducentes_a_gol_Local  \
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                     NaN                              NaN
# 4                                     NaN                              NaN
#
#    Errores_conducentes_a_gol_Visitante  Saves_Home  Saves_Away  \
# 0                                  NaN         NaN         NaN
# 1                                  NaN         NaN         NaN
# 2                                  NaN         NaN         NaN
# 3                                  NaN         NaN         NaN
# 4                                  NaN         NaN         NaN
#
#    xGOT_enfrentados_Local  xGOT_enfrentados_Visitante  Goles_evitados_Local  \
# 0                     NaN                         NaN                   NaN
# 1                     NaN                         NaN                   NaN
# 2                     NaN                         NaN                   NaN
# 3                     NaN                         NaN                   NaN
# 4                     NaN                         NaN                   NaN
#
#    Goles_evitados_Visitante  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                    Announcement_Home  \
# 0  BundesligaLaLiga EA SportsLaLiga HypermotionCo...
# 1  BundesligaLaLiga EA SportsLaLiga HypermotionCo...
# 2  BundesligaLaLiga EA SportsLaLiga HypermotionCo...
# 3  BundesligaLaLiga EA SportsLaLiga HypermotionCo...
# 4  BundesligaLaLiga EA SportsLaLiga HypermotionCo...
#
#                                    Announcement_Away   Checkbox_Label_Home  \
# 0  Champions LeagueEuropa LeagueConference League...  checkbox label label
# 1  Champions LeagueEuropa LeagueConference League...  checkbox label label
# 2  Champions LeagueEuropa LeagueConference League...  checkbox label label
# 3  Champions LeagueEuropa LeagueConference League...  checkbox label label
# 4  Champions LeagueEuropa LeagueConference League...  checkbox label label
#
#     Checkbox_Label_Away  Tarjetas_rojas_Local  Tarjetas_rojas_Visitante  \
# 0  checkbox label label                   NaN                       NaN
# 1  checkbox label label                   NaN                       NaN
# 2  checkbox label label                   NaN                       NaN
# 3  checkbox label label                   NaN                       NaN
# 4  checkbox label label                   NaN                       NaN
#
#   2Córneres2_Local 2Córneres2_Visitante 2Córneres3_Local 2Córneres3_Visitante  \
# 0              NaN                  NaN              NaN                  NaN
# 1              NaN                  NaN              NaN                  NaN
# 2              NaN                  NaN              NaN                  NaN
# 3              NaN                  NaN              NaN                  NaN
# 4              NaN                  NaN              NaN                  NaN
#
#   4Córneres4_Local 4Córneres4_Visitante 0Córneres8_Local 0Córneres8_Visitante  \
# 0              NaN                  NaN              NaN                  NaN
# 1              NaN                  NaN              NaN                  NaN
# 2              NaN                  NaN              NaN                  NaN
# 3              NaN                  NaN              NaN                  NaN
# 4              NaN                  NaN              NaN                  NaN
#
#   3Córneres1_Local 3Córneres1_Visitante 5Córneres6_Local 5Córneres6_Visitante  \
# 0              NaN                  NaN              NaN                  NaN
# 1              NaN                  NaN              NaN                  NaN
# 2              NaN                  NaN              NaN                  NaN
# 3              NaN                  NaN              NaN                  NaN
# 4              NaN                  NaN              NaN                  NaN
#
#   3Córneres6_Local 3Córneres6_Visitante Gol1_-_0_Local Gol1_-_0_Visitante  \
# 0              NaN                  NaN            NaN                NaN
# 1              NaN                  NaN            NaN                NaN
# 2              NaN                  NaN            NaN                NaN
# 3              NaN                  NaN            NaN                NaN
# 4              NaN                  NaN            NaN                NaN
#
#   1_-_1Gol_Local 1_-_1Gol_Visitante Sustitución_-_Entra_Local  \
# 0            NaN                NaN                       90'
# 1            NaN                NaN                       75'
# 2            NaN                NaN                       85'
# 3            NaN                NaN                       87'
# 4            NaN                NaN                     90+3'
#
#   Sustitución_-_Entra_Visitante 1_-_2Gol_Local 1_-_2Gol_Visitante  \
# 0             Khurelbaataryn T.            NaN                NaN
# 1                      Aakib M.            NaN                NaN
# 2                      Jibon N.            NaN                NaN
# 3                      Cheng M.            NaN                NaN
# 4                     Lepcha C.            NaN                NaN
#
#   2Córneres16_Local 2Córneres16_Visitante 7Córneres5_Local  \
# 0               NaN                   NaN              NaN
# 1               NaN                   NaN              NaN
# 2               NaN                   NaN              NaN
# 3               NaN                   NaN              NaN
# 4               NaN                   NaN              NaN
#
#   7Córneres5_Visitante 5Córneres4_Local 5Córneres4_Visitante 0_-_2Gol_Local  \
# 0                  NaN              NaN                  NaN            NaN
# 1                  NaN              NaN                  NaN            NaN
# 2                  NaN              NaN                  NaN            NaN
# 3                  NaN              NaN                  NaN            NaN
# 4                  NaN              NaN                  NaN            NaN
#
#   0_-_2Gol_Visitante 10Córneres4_Local 10Córneres4_Visitante 5Córneres2_Local  \
# 0                NaN               NaN                   NaN              NaN
# 1                NaN               NaN                   NaN              NaN
# 2                NaN               NaN                   NaN              NaN
# 3                NaN               NaN                   NaN              NaN
# 4                NaN               NaN                   NaN              NaN
#
#   5Córneres2_Visitante 4Córneres1_Local 4Córneres1_Visitante 2Córneres5_Local  \
# 0                  NaN              NaN                  NaN              NaN
# 1                  NaN              NaN                  NaN              NaN
# 2                  NaN              NaN                  NaN              NaN
# 3                  NaN              NaN                  NaN              NaN
# 4                  NaN              NaN                  NaN              NaN
#
#   2Córneres5_Visitante 11Córneres0_Local 11Córneres0_Visitante  \
# 0                  NaN               NaN                   NaN
# 1                  NaN               NaN                   NaN
# 2                  NaN               NaN                   NaN
# 3                  NaN               NaN                   NaN
# 4                  NaN               NaN                   NaN
#
#   2Córneres1_Local 2Córneres1_Visitante 0_-_1Gol_Local 0_-_1Gol_Visitante  \
# 0              NaN                  NaN            NaN                NaN
# 1              NaN                  NaN            NaN                NaN
# 2              NaN                  NaN            NaN                NaN
# 3              NaN                  NaN            NaN                NaN
# 4              NaN                  NaN            NaN                NaN
#
#   0_-_3Gol_Local 0_-_3Gol_Visitante 0_-_4Gol_Local 0_-_4Gol_Visitante  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#   Penalti_fallado_Local Penalti_fallado_Visitante Gol2_-_0_Local  \
# 0                   NaN                       NaN            NaN
# 1                   NaN                       NaN            NaN
# 2                   NaN                       NaN            NaN
# 3                   NaN                       NaN            NaN
# 4                   NaN                       NaN            NaN
#
#   Gol2_-_0_Visitante 2_-_1Gol_Local 2_-_1Gol_Visitante Gol1_-_1_Local  \
# 0                NaN            NaN                NaN            NaN
# 1                NaN            NaN                NaN            NaN
# 2                NaN            NaN                NaN            NaN
# 3                NaN            NaN                NaN            NaN
# 4                NaN            NaN                NaN            NaN
#
#   Gol1_-_1_Visitante Gol3_-_0_Local Gol3_-_0_Visitante Gol4_-_0_Local  \
# 0                NaN            NaN                NaN            NaN
# 1                NaN            NaN                NaN            NaN
# 2                NaN            NaN                NaN            NaN
# 3                NaN            NaN                NaN            NaN
# 4                NaN            NaN                NaN            NaN
#
#   Gol4_-_0_Visitante Gol5_-_0_Local Gol5_-_0_Visitante Gol1_-_2_Local  \
# 0                NaN            NaN                NaN            NaN
# 1                NaN            NaN                NaN            NaN
# 2                NaN            NaN                NaN            NaN
# 3                NaN            NaN                NaN            NaN
# 4                NaN            NaN                NaN            NaN
#
#   Gol1_-_2_Visitante 1_-_3Gol_Local 1_-_3Gol_Visitante 1_-_4Gol_Local  \
# 0                NaN            NaN                NaN            NaN
# 1                NaN            NaN                NaN            NaN
# 2                NaN            NaN                NaN            NaN
# 3                NaN            NaN                NaN            NaN
# 4                NaN            NaN                NaN            NaN
#
#   1_-_4Gol_Visitante 1_-_5Gol_Local 1_-_5Gol_Visitante Penalti1_-_1_Local  \
# 0                NaN            NaN                NaN                NaN
# 1                NaN            NaN                NaN                NaN
# 2                NaN            NaN                NaN                NaN
# 3                NaN            NaN                NaN                NaN
# 4                NaN            NaN                NaN                NaN
#
#   Penalti1_-_1_Visitante Tarjeta_amarilla_Local Tarjeta_amarilla_Visitante  \
# 0                    NaN                    NaN                        NaN
# 1                    NaN                    NaN                        NaN
# 2                    NaN                    NaN                        NaN
# 3                    NaN                    NaN                        NaN
# 4                    NaN                    NaN                        NaN
#
#   0_-_5Gol_Local 0_-_5Gol_Visitante 0_-_7Gol_Local 0_-_7Gol_Visitante  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#   0_-_1Gol_en_propia_puerta_Local 0_-_1Gol_en_propia_puerta_Visitante  \
# 0                             NaN                                 NaN
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
# 3                             NaN                                 NaN
# 4                             NaN                                 NaN
#
#   Gol2_-_2_Local Gol2_-_2_Visitante Gol3_-_2_Local Gol3_-_2_Visitante  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#   Gol4_-_2_Local Gol4_-_2_Visitante Gol2_-_1_Local Gol2_-_1_Visitante  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#   Penalti3_-_2_Local Penalti3_-_2_Visitante Gol5_-_2_Local Gol5_-_2_Visitante  \
# 0                NaN                    NaN            NaN                NaN
# 1                NaN                    NaN            NaN                NaN
# 2                NaN                    NaN            NaN                NaN
# 3                NaN                    NaN            NaN                NaN
# 4                NaN                    NaN            NaN                NaN
#
#   Gol6_-_2_Local Gol6_-_2_Visitante Penalti1_-_0_Local Penalti1_-_0_Visitante  \
# 0            NaN                NaN                NaN                    NaN
# 1            NaN                NaN                NaN                    NaN
# 2            NaN                NaN                NaN                    NaN
# 3            NaN                NaN                NaN                    NaN
# 4            NaN                NaN                NaN                    NaN
#
#   Gol6_-_0_Local Gol6_-_0_Visitante Penalti2_-_0_Local Penalti2_-_0_Visitante  \
# 0            NaN                NaN                NaN                    NaN
# 1            NaN                NaN                NaN                    NaN
# 2            NaN                NaN                NaN                    NaN
# 3            NaN                NaN                NaN                    NaN
# 4            NaN                NaN                NaN                    NaN
#
#   M+_Liga_de_Campeones,_Local M+_Liga_de_Campeones,_Visitante  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#   Gol_anulado_-_fuera_de_juego_Local Gol_anulado_-_fuera_de_juego_Visitante  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
#
#   Enciso_J._Local Enciso_J._Visitante Movistar+_Lite,_Local  \
# 0             NaN                 NaN                   NaN
# 1             NaN                 NaN                   NaN
# 2             NaN                 NaN                   NaN
# 3             NaN                 NaN                   NaN
# 4             NaN                 NaN                   NaN
#
#   Movistar+_Lite,_Visitante Gol_anulado_-_mano_Local  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
#   Gol_anulado_-_mano_Visitante 4Córneres2_Local 4Córneres2_Visitante  \
# 0                          NaN              NaN                  NaN
# 1                          NaN              NaN                  NaN
# 2                          NaN              NaN                  NaN
# 3                          NaN              NaN                  NaN
# 4                          NaN              NaN                  NaN
#
#   3_-_1Gol_Local 3_-_1Gol_Visitante 5Córneres1_Local 5Córneres1_Visitante  \
# 0            NaN                NaN              NaN                  NaN
# 1            NaN                NaN              NaN                  NaN
# 2            NaN                NaN              NaN                  NaN
# 3            NaN                NaN              NaN                  NaN
# 4            NaN                NaN              NaN                  NaN
#
#   Gol7_-_0_Local Gol7_-_0_Visitante 6Córneres3_Local 6Córneres3_Visitante  \
# 0            NaN                NaN              NaN                  NaN
# 1            NaN                NaN              NaN                  NaN
# 2            NaN                NaN              NaN                  NaN
# 3            NaN                NaN              NaN                  NaN
# 4            NaN                NaN              NaN                  NaN
#
#   Falta_Local Falta_Visitante M+_Liga_de_Campeones_3,_Local  \
# 0         NaN             NaN                           NaN
# 1         NaN             NaN                           NaN
# 2         NaN             NaN                           NaN
# 3         NaN             NaN                           NaN
# 4         NaN             NaN                           NaN
#
#   M+_Liga_de_Campeones_3,_Visitante 73%(294/402)Pases81%(464/574)_Local  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#   73%(294/402)Pases81%(464/574)_Visitante 10Faltas11_Local  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
#
#   10Faltas11_Visitante 80%(335/421)Pases75%(314/420)_Local  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#   80%(335/421)Pases75%(314/420)_Visitante 4Faltas11_Local 4Faltas11_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   79%(202/255)Pases83%(433/523)_Local 79%(202/255)Pases83%(433/523)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   24Faltas20_Local 24Faltas20_Visitante 80%(427/535)Pases76%(298/392)_Local  \
# 0              NaN                  NaN                                 NaN
# 1              NaN                  NaN                                 NaN
# 2              NaN                  NaN                                 NaN
# 3              NaN                  NaN                                 NaN
# 4              NaN                  NaN                                 NaN
#
#   80%(427/535)Pases76%(298/392)_Visitante 10Faltas28_Local  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
#
#   10Faltas28_Visitante 78%(299/382)Pases84%(529/627)_Local  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#   78%(299/382)Pases84%(529/627)_Visitante 8Faltas13_Local 8Faltas13_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   17Faltas6_Local 17Faltas6_Visitante 19Faltas10_Local 19Faltas10_Visitante  \
# 0             NaN                 NaN              NaN                  NaN
# 1             NaN                 NaN              NaN                  NaN
# 2             NaN                 NaN              NaN                  NaN
# 3             NaN                 NaN              NaN                  NaN
# 4             NaN                 NaN              NaN                  NaN
#
#   75%(449/600)Pases70%(284/407)_Local 75%(449/600)Pases70%(284/407)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   9Faltas9_Local 9Faltas9_Visitante 58%(108/185)Pases88%(523/596)_Local  \
# 0            NaN                NaN                                 NaN
# 1            NaN                NaN                                 NaN
# 2            NaN                NaN                                 NaN
# 3            NaN                NaN                                 NaN
# 4            NaN                NaN                                 NaN
#
#   58%(108/185)Pases88%(523/596)_Visitante 16Faltas4_Local 16Faltas4_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   0_-_6Gol_Local 0_-_6Gol_Visitante 0_-_8Penalti_Local 0_-_8Penalti_Visitante  \
# 0            NaN                NaN                NaN                    NaN
# 1            NaN                NaN                NaN                    NaN
# 2            NaN                NaN                NaN                    NaN
# 3            NaN                NaN                NaN                    NaN
# 4            NaN                NaN                NaN                    NaN
#
#   Gol_en_propia_puerta1_-_0_Local Gol_en_propia_puerta1_-_0_Visitante  \
# 0                             NaN                                 NaN
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
# 3                             NaN                                 NaN
# 4                             NaN                                 NaN
#
#   M+_Liga_de_Campeones_2,_Local M+_Liga_de_Campeones_2,_Visitante  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#   78%(260/332)Pases85%(588/694)_Local 78%(260/332)Pases85%(588/694)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   9Faltas6_Local 9Faltas6_Visitante Gol3_-_1_Local Gol3_-_1_Visitante  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#   Gol4_-_1_Local Gol4_-_1_Visitante Gol5_-_1_Local Gol5_-_1_Visitante  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#   Gol6_-_1_Local Gol6_-_1_Visitante Gol7_-_1_Local Gol7_-_1_Visitante  \
# 0            NaN                NaN            NaN                NaN
# 1            NaN                NaN            NaN                NaN
# 2            NaN                NaN            NaN                NaN
# 3            NaN                NaN            NaN                NaN
# 4            NaN                NaN            NaN                NaN
#
#   Gol8_-_1_Local Gol8_-_1_Visitante Herrera_Y._Local Herrera_Y._Visitante  \
# 0            NaN                NaN              NaN                  NaN
# 1            NaN                NaN              NaN                  NaN
# 2            NaN                NaN              NaN                  NaN
# 3            NaN                NaN              NaN                  NaN
# 4            NaN                NaN              NaN                  NaN
#
#   Martínez_J._Local Martínez_J._Visitante 79%(358/451)Pases82%(436/532)_Local  \
# 0               NaN                   NaN                                 NaN
# 1               NaN                   NaN                                 NaN
# 2               NaN                   NaN                                 NaN
# 3               NaN                   NaN                                 NaN
# 4               NaN                   NaN                                 NaN
#
#   79%(358/451)Pases82%(436/532)_Visitante 10Faltas8_Local 10Faltas8_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   80%(344/431)Pases78%(290/374)_Local 80%(344/431)Pases78%(290/374)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   15Faltas23_Local 15Faltas23_Visitante 69%(281/407)Pases66%(188/283)_Local  \
# 0              NaN                  NaN                                 NaN
# 1              NaN                  NaN                                 NaN
# 2              NaN                  NaN                                 NaN
# 3              NaN                  NaN                                 NaN
# 4              NaN                  NaN                                 NaN
#
#   69%(281/407)Pases66%(188/283)_Visitante 11Faltas16_Local  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
#
#   11Faltas16_Visitante 80%(419/522)Pases77%(306/397)_Local  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#   80%(419/522)Pases77%(306/397)_Visitante 10Faltas17_Local  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
#
#   10Faltas17_Visitante 84%(453/542)Pases62%(141/228)_Local  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#   84%(453/542)Pases62%(141/228)_Visitante 11Faltas13_Local  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
#
#   11Faltas13_Visitante 70%(184/264)Pases91%(689/760)_Local  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#   70%(184/264)Pases91%(689/760)_Visitante 11Faltas11_Local  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
#
#   11Faltas11_Visitante 81%(375/464)Pases81%(352/436)_Local  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#   81%(375/464)Pases81%(352/436)_Visitante 12Faltas7_Local 12Faltas7_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   11Faltas9_Local 11Faltas9_Visitante 2_-_2Penalti_Local  \
# 0             NaN                 NaN                NaN
# 1             NaN                 NaN                NaN
# 2             NaN                 NaN                NaN
# 3             NaN                 NaN                NaN
# 4             NaN                 NaN                NaN
#
#   2_-_2Penalti_Visitante 3_-_3Gol_Local 3_-_3Gol_Visitante 0_-_1Penalti_Local  \
# 0                    NaN            NaN                NaN                NaN
# 1                    NaN            NaN                NaN                NaN
# 2                    NaN            NaN                NaN                NaN
# 3                    NaN            NaN                NaN                NaN
# 4                    NaN            NaN                NaN                NaN
#
#   0_-_1Penalti_Visitante 2_-_3Gol_Local 2_-_3Gol_Visitante Ugarte_M._Local  \
# 0                    NaN            NaN                NaN             NaN
# 1                    NaN            NaN                NaN             NaN
# 2                    NaN            NaN                NaN             NaN
# 3                    NaN            NaN                NaN             NaN
# 4                    NaN            NaN                NaN             NaN
#
#   Ugarte_M._Visitante Olivera_M._Local Olivera_M._Visitante  \
# 0                 NaN              NaN                  NaN
# 1                 NaN              NaN                  NaN
# 2                 NaN              NaN                  NaN
# 3                 NaN              NaN                  NaN
# 4                 NaN              NaN                  NaN
#
#   79%(405/512)Pases63%(166/262)_Local 79%(405/512)Pases63%(166/262)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   9Faltas13_Local 9Faltas13_Visitante 80%(325/407)Pases83%(382/462)_Local  \
# 0             NaN                 NaN                                 NaN
# 1             NaN                 NaN                                 NaN
# 2             NaN                 NaN                                 NaN
# 3             NaN                 NaN                                 NaN
# 4             NaN                 NaN                                 NaN
#
#   80%(325/407)Pases83%(382/462)_Visitante 13Faltas3_Local 13Faltas3_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   82%(313/384)Pases85%(462/541)_Local 82%(313/384)Pases85%(462/541)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   17Faltas4_Local 17Faltas4_Visitante 81%(350/431)Pases75%(276/366)_Local  \
# 0             NaN                 NaN                                 NaN
# 1             NaN                 NaN                                 NaN
# 2             NaN                 NaN                                 NaN
# 3             NaN                 NaN                                 NaN
# 4             NaN                 NaN                                 NaN
#
#   81%(350/431)Pases75%(276/366)_Visitante 22Faltas21_Local  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
#
#   22Faltas21_Visitante 62%(200/324)Pases73%(365/498)_Local  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#   62%(200/324)Pases73%(365/498)_Visitante 24Faltas22_Local  \
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# 3                                     NaN              NaN
# 4                                     NaN              NaN
#
#   24Faltas22_Visitante 82%(467/568)Pases74%(284/384)_Local  \
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
#
#   82%(467/568)Pases74%(284/384)_Visitante 9Faltas7_Local 9Faltas7_Visitante  \
# 0                                     NaN            NaN                NaN
# 1                                     NaN            NaN                NaN
# 2                                     NaN            NaN                NaN
# 3                                     NaN            NaN                NaN
# ...
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   83%(477/576)Pases70%(233/331)_Local 83%(477/576)Pases70%(233/331)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   9Faltas25_Local 9Faltas25_Visitante 91%(576/633)Pases82%(329/402)_Local  \
# 0             NaN                 NaN                                 NaN
# 1             NaN                 NaN                                 NaN
# 2             NaN                 NaN                                 NaN
# 3             NaN                 NaN                                 NaN
# 4             NaN                 NaN                                 NaN
#
#   91%(576/633)Pases82%(329/402)_Visitante 9Faltas17_Local 9Faltas17_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   88%(306/348)Pases91%(570/625)_Local 88%(306/348)Pases91%(570/625)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   78%(227/292)Pases87%(521/599)_Local 78%(227/292)Pases87%(521/599)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   76%(236/312)Pases84%(406/485)_Local 76%(236/312)Pases84%(406/485)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   81%(291/361)Pases86%(432/505)_Local 81%(291/361)Pases86%(432/505)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   71%(296/415)Pases71%(244/342)_Local 71%(296/415)Pases71%(244/342)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   90%(498/556)Pases86%(453/528)_Local 90%(498/556)Pases86%(453/528)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   14Faltas7_Local 14Faltas7_Visitante 78%(368/469)Pases77%(328/426)_Local  \
# 0             NaN                 NaN                                 NaN
# 1             NaN                 NaN                                 NaN
# 2             NaN                 NaN                                 NaN
# 3             NaN                 NaN                                 NaN
# 4             NaN                 NaN                                 NaN
#
#   78%(368/469)Pases77%(328/426)_Visitante 74%(261/352)Pases78%(315/402)_Local  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   74%(261/352)Pases78%(315/402)_Visitante 65%(164/251)Pases89%(626/704)_Local  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   65%(164/251)Pases89%(626/704)_Visitante 69%(173/250)Pases90%(630/702)_Local  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   69%(173/250)Pases90%(630/702)_Visitante 19Faltas8_Local 19Faltas8_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   80%(262/327)Pases85%(404/477)_Local 80%(262/327)Pases85%(404/477)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   16Faltas8_Local 16Faltas8_Visitante 83%(434/526)Pases80%(273/343)_Local  \
# 0             NaN                 NaN                                 NaN
# 1             NaN                 NaN                                 NaN
# 2             NaN                 NaN                                 NaN
# 3             NaN                 NaN                                 NaN
# 4             NaN                 NaN                                 NaN
#
#   83%(434/526)Pases80%(273/343)_Visitante 88%(429/489)Pases75%(207/276)_Local  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   88%(429/489)Pases75%(207/276)_Visitante 77%(272/352)Pases86%(433/505)_Local  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   77%(272/352)Pases86%(433/505)_Visitante 76%(233/306)Pases88%(537/613)_Local  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   76%(233/306)Pases88%(537/613)_Visitante 18Faltas3_Local 18Faltas3_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   77%(266/346)Pases85%(398/471)_Local 77%(266/346)Pases85%(398/471)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   82%(274/334)Pases91%(637/700)_Local 82%(274/334)Pases91%(637/700)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   85%(304/359)Pases90%(512/570)_Local 85%(304/359)Pases90%(512/570)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   84%(493/588)Pases71%(221/310)_Local 84%(493/588)Pases71%(221/310)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   84%(444/528)Pases80%(356/443)_Local 84%(444/528)Pases80%(356/443)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   10Faltas5_Local 10Faltas5_Visitante 89%(513/575)Pases74%(244/328)_Local  \
# 0             NaN                 NaN                                 NaN
# 1             NaN                 NaN                                 NaN
# 2             NaN                 NaN                                 NaN
# 3             NaN                 NaN                                 NaN
# 4             NaN                 NaN                                 NaN
#
#   89%(513/575)Pases74%(244/328)_Visitante 84%(410/486)Pases79%(328/417)_Local  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
#   84%(410/486)Pases79%(328/417)_Visitante 5Faltas11_Local 5Faltas11_Visitante  \
# 0                                     NaN             NaN                 NaN
# 1                                     NaN             NaN                 NaN
# 2                                     NaN             NaN                 NaN
# 3                                     NaN             NaN                 NaN
# 4                                     NaN             NaN                 NaN
#
#   73%(263/360)Pases74%(264/359)_Local 73%(263/360)Pases74%(264/359)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   82%(347/422)Pases86%(431/501)_Local 82%(347/422)Pases86%(431/501)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   68%(282/413)Pases58%(180/308)_Local 68%(282/413)Pases58%(180/308)_Visitante  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#    Home_Score  Away_Score  Home_Market_Value_Millions_EUR  \
# 0       915.0       903.0                           0.024
# 1       925.0       886.0                           0.016
# 2       923.0       907.0                           0.057
# 3       970.0       888.0                           0.099
# 4       917.0       907.0                           0.037
#
#    Away_Market_Value_Millions_EUR
# 0                           0.035
# 1                           0.040
# 2                           0.315
# 3                           0.154
# 4                           0.010

# %% [markdown]
# The scraper has downloaded many variables, some of which we do not want to use because they are poorly populated or assumed to have low predictive power, so we remove them. We also drop columns that are not relevant and some variables that are highly correlated with others like for example Total_Shots_Home and Shots_on_Target_Away.

# %%
# identifying highly correlated variables (above 0.7) to consider dropping them
corr_matrix = df.corr(numeric_only=True).abs()

upper = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
)

to_drop = [
    column for column in upper.columns
    if any(upper[column] > 0.7)
]

# %%
na_pct = df.isna().mean().sort_values(ascending=False) * 100
print(len(na_pct[na_pct > 50]))
print(len(na_pct))

#keep these two metrics for their explanatory power and because they are not highly correlated with other features
col_keep = ['Expected_Goals_Home_(xG)', 'Expected_Goals_Away_(xG)']

col_delete = [
    c for c in df.columns 
    if c not in col_keep          
    and df[c].isna().mean() > 0.5        
]

df = df.drop(columns=col_delete)
print(df.shape[1])
# Out:
# 2742
# 2782
# 42

# %% [markdown]
# **Figure 1.** Percentage of missing values per variable in the raw dataset (after all joins, before column selection). The dashed line marks the 50% threshold used to drop uninformative variables.

# %%
#  Figure 1: Missing data before cleaning 
na_pct_raw = df.isna().mean().sort_values(ascending=False) * 100
na_with_values = na_pct_raw[na_pct_raw > 0]

fig, ax = plt.subplots(figsize=(10, 4))
bars = ax.bar(range(len(na_with_values)), na_with_values.values,
              color='white', edgecolor='black', linewidth=0.7)
for bar in bars:
    bar.set_hatch('///')
ax.axhline(50, color='black', linestyle='--', linewidth=1.2, label='50% threshold')
ax.set_xlabel('Variables (sorted by % missing)', fontsize=11)
ax.set_ylabel('% Missing values', fontsize=11)
ax.set_title('Figure 1. Missing values per variable after column selection', fontsize=12)
ax.set_xticks([])
ax.legend(fontsize=10)
plt.tight_layout()
plt.show()

print(f'Variables with >50% NaN (protected variables): {(na_pct_raw > 50).sum()}')
print(f'Variables with any NaN: {(na_pct_raw > 0).sum()}')
print(f'Complete variables (0% NaN): {(na_pct_raw == 0).sum()}')
# Out:
# Variables with >50% NaN (protected variables): 2
# Variables with any NaN: 37
# Complete variables (0% NaN): 5

# %%
# Define the strict list of variables for the model
# We removed those with more than 50% missing values
# We also identified those highly correlated with other variables
# We handle this by defining the following list, which omits several features
columns = [
    'Date', 'Home_Team', 'Away_Team', 'Result', 
    'Expected_Goals_Home_(xG)', 'Expected_Goals_Away_(xG)', 
    'Possession_Home', 'Possession_Away', 
    'Shots_on_Target_Home', 'Shots_on_Target_Away', 
    'Corners_Home', 'Corners_Away', 
    'Passes_Home', 'Passes_Away', 
    'Yellow_Cards_Home', 'Yellow_Cards_Away',
    'Fouls_Home', 'Fouls_Away', 
    'Saves_Home', 'Saves_Away',
    'Home_Score', 'Away_Score',
    'Home_Market_Value_Millions_EUR', 'Away_Market_Value_Millions_EUR'
]

# Filter using list comprehension
existing_columns = [col for col in columns if col in df.columns]

# Overwrite the DataFrame with the validated subset
df = df[existing_columns]

# %%
# resulting dataset
pd.set_option('display.max_columns', None)
print(df.shape)
df.head()
df.describe()
# Out:
# (3144, 24)
#                                 Date  Expected_Goals_Home_(xG)  \
# count                           3144               1032.000000
# mean   2023-09-28 15:34:21.068702208                  1.464564
# min              2019-06-06 00:00:00                  0.000000
# 25%              2022-01-30 00:00:00                  0.670000
# 50%              2024-03-21 00:00:00                  1.250000
# 75%              2025-03-20 00:00:00                  2.030000
# max              2026-06-28 00:00:00                  9.570000
# std                              NaN                  1.072548
#
#        Expected_Goals_Away_(xG)  Shots_on_Target_Home  Shots_on_Target_Away  \
# count               1032.000000           2495.000000           2495.000000
# mean                   1.125388              4.490982              3.647695
# min                    0.000000              0.000000              0.000000
# 25%                    0.450000              2.000000              2.000000
# 50%                    0.930000              4.000000              3.000000
# 75%                    1.530000              6.000000              5.000000
# max                    6.340000             22.000000             25.000000
# std                    0.898599              3.105957              2.713189
#
#        Corners_Home  Corners_Away  Yellow_Cards_Home  Yellow_Cards_Away  \
# count   2495.000000   2495.000000        2390.000000        2390.000000
# mean       4.989980      4.030461           1.841841           2.054393
# min        0.000000      0.000000           0.000000           0.000000
# 25%        3.000000      2.000000           1.000000           1.000000
# 50%        4.000000      4.000000           2.000000           2.000000
# 75%        7.000000      6.000000           3.000000           3.000000
# max       20.000000     20.000000           7.000000          11.000000
# std        3.278001      2.895098           1.338207           1.392879
#
#         Fouls_Home   Fouls_Away   Saves_Home   Saves_Away   Home_Score  \
# count  2328.000000  2328.000000  2411.000000  2411.000000  3122.000000
# mean     12.225086    12.278780     2.479469     2.973455  1330.970368
# min       0.000000     0.000000     0.000000     0.000000   726.030000
# 25%       9.000000     9.000000     1.000000     1.000000  1140.142500
# 50%      12.000000    12.000000     2.000000     3.000000  1343.385000
# 75%      15.000000    15.000000     4.000000     4.000000  1511.135000
# max      33.000000    37.000000    14.000000    15.000000  1901.480000
# std       4.408456     4.513365     2.028401     2.245909   253.908292
#
#         Away_Score  Home_Market_Value_Millions_EUR  \
# count  3121.000000                     3141.000000
# mean   1321.980381                        6.665954
# min     727.950000                        0.000000
# 25%    1135.420000                        0.297000
# 50%    1334.370000                        1.380000
# 75%    1500.520000                        7.640000
# max    1901.480000                       58.580000
# std     248.866940                       11.295491
#
#        Away_Market_Value_Millions_EUR
# count                     3140.000000
# mean                         6.212583
# min                          0.000000
# 25%                          0.285000
# 50%                          1.330000
# 75%                          7.405000
# max                         58.580000
# std                         10.847050

# %% [markdown]
# Data such as xG is not available for very old dates, so we keep only matches with more recent dates.

# %%
df['Year'] = df['Date'].dt.year
matches_per_year = df.groupby('Year').size()

xg_cols = ['Expected_Goals_Home_(xG)', 'Expected_Goals_Away_(xG)']
pct_nans = df.groupby('Year')[xg_cols].apply(lambda x: x.isna().mean().mean() * 100)

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# Figure 2: Match volume per year
bars = axes[0].bar(range(len(matches_per_year)), matches_per_year.values,
                   color='white', edgecolor='black', linewidth=1, hatch='///')
axes[0].set_xticks(range(len(matches_per_year)))
axes[0].set_xticklabels(matches_per_year.index, rotation=0, fontsize=10)
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Number of matches')
axes[0].set_title('Figure 2. Matches per year', fontsize=11)

# Figure 3: xG missingness per year
bars = axes[1].bar(range(len(pct_nans)), pct_nans.values,
                   color='white', edgecolor='black', linewidth=1, hatch='xxx')
axes[1].axvline(pct_nans.index.get_loc(2023) - 0.5, color='black',
                linestyle='--', linewidth=1.2, label='2023 cut-off')
axes[1].set_xticks(range(len(pct_nans)))
axes[1].set_xticklabels(pct_nans.index, rotation=0, fontsize=10)
axes[1].set_xlabel('Year')
axes[1].set_ylabel('% missing xG')
axes[1].set_ylim(0, 105)
axes[1].set_title('Figure 3. Missing xG values per year', fontsize=11)
axes[1].legend(fontsize=9)

plt.tight_layout()
plt.show()

# %%
# Remove very old dates because theres little information available
threshold_date = pd.to_datetime('2023-01-01')
df = df[df['Date'] >= threshold_date].copy()
print(df.shape)
df.head()
# Out:
# (2017, 25)
#            Date   Home_Team          Away_Team         Result  \
# 1127 2023-03-23    Portugal      Liechtenstein  4-0Finalizado
# 1128 2023-03-23  San Marino  Irlanda del Norte  0-2Finalizado
# 1129 2023-03-23  Kazajistán          Eslovenia  1-2Finalizado
# 1130 2023-03-23  Eslovaquia         Luxemburgo  0-0Finalizado
# 1131 2023-03-23      Italia         Inglaterra  1-2Finalizado
#
#       Expected_Goals_Home_(xG)  Expected_Goals_Away_(xG) Possession_Home  \
# 1127                      4.16                      0.03             71%
# 1128                      0.03                      1.79             30%
# 1129                      0.63                      1.49             43%
# 1130                      1.25                      0.61             48%
# 1131                      1.16                      2.07             49%
#
#      Possession_Away  Shots_on_Target_Home  Shots_on_Target_Away  \
# 1127             29%                  11.0                   1.0
# 1128             70%                   1.0                   4.0
# 1129             57%                   2.0                   6.0
# 1130             52%                   3.0                   2.0
# 1131             51%                   1.0                   4.0
#
#       Corners_Home  Corners_Away   Passes_Home   Passes_Away  \
# 1127          12.0           0.0  91%(677/740)   56%(91/162)
# 1128           0.0           9.0  71%(205/287)  87%(582/668)
# 1129           3.0           4.0  75%(225/301)  86%(408/474)
# 1130           9.0           2.0  80%(321/401)  78%(334/428)
# 1131           7.0           3.0  81%(420/516)  82%(318/389)
#
#       Yellow_Cards_Home  Yellow_Cards_Away  Fouls_Home  Fouls_Away  \
# 1127                NaN                NaN         5.0         6.0
# 1128                0.0                1.0        16.0         9.0
# 1129                2.0                1.0        17.0        11.0
# 1130                0.0                2.0        11.0        17.0
# 1131                3.0                5.0        13.0         6.0
#
#       Saves_Home  Saves_Away  Home_Score  Away_Score  \
# 1127         1.0         7.0     1702.54      859.84
# 1128         2.0         1.0      763.15     1396.55
# 1129         4.0         1.0     1163.09     1389.06
# 1130         2.0         3.0     1425.58     1245.35
# 1131         2.0         0.0     1723.56     1774.19
#
#       Home_Market_Value_Millions_EUR  Away_Market_Value_Millions_EUR  Year
# 1127                          38.670                           0.026  2023
# 1128                           0.044                           3.470  2023
# 1129                           0.652                           4.020  2023
# 1130                           2.300                           0.639  2023
# 1131                          13.730                          52.430  2023

# %% [markdown]
# ## Feature Engineering
#
# Some variables come in unusual formats after scraping. For example, Passes_Home comes as 91%(814/897). We will extract the individual values to create usable variables for modelling.

# %% [markdown]
# ### Cleaning the Result Variable

# %%
def clean_flashcore_results(text):
    text = str(text).strip()
    
    # if the match was decided in 90 minutes (e.g. "2-1Finalizado")
    match_fin = re.match(r'^(\d+-\d+)\s*Finalizado', text)
    if match_fin:
        result_90  = match_fin.group(1)
        return pd.Series([result_90 , None, None])
        
    # if the match was decided in extra time (e.g. "1-0(0-0)Tras la prórroga")
    # We capture 1-0 as the final score and 0-0 as the regular-time score
    match_pro = re.match(r'^(\d+-\d+)\s*\(\s*(\d+-\d+)\s*\)\s*Tras la prórroga', text)
    if match_pro:
        result_120 = match_pro.group(1) # Final score after 120 min (1-0)
        result_90  = match_pro.group(2)  # Score at 90 min (0-0)
        
        # FIX: We assign the draw (0-0) as the main 90-min result
        # and store 1-0 in the extra time column
        return pd.Series([result_90 , result_120, None])
        
    # if the match decided on penalties (e.g. "2-1(1-1)Tras los penaltis")
    match_pen = re.match(r'^(\d+-\d+)\s*\(\s*(\d+-\d+)\s*\)\s*Tras los penaltis', text)
    if match_pen:
        result_penaltis = match_pen.group(1) # Penalty shootout result (2-1)
        result_120 = match_pen.group(2)      # Match score after 120 min (1-1)
        
        # We assign the draw (1-1) as the main result since both stages ended in a draw
        return pd.Series([result_120, result_120, result_penaltis])
    
    # if match lost by walkover (e.g. "0-3Por perdido")
    match_walkover = re.match(r'^(\d+-\d+)\s*Por perdido', text)
    if match_walkover:
        return pd.Series([match_walkover.group(1), None, None])    

    # Residual case (postponed, suspended, or other formats)
    return pd.Series([text, None, None])


new_col = ['Result', 'Extra_Time_Result', 'Penalty_Shootout_Result']
df[new_col] = df['Result'].apply(clean_flashcore_results)
print(len(df))
print(df['Result'].isna().sum())
print(df[['Result', 'Extra_Time_Result', 'Penalty_Shootout_Result']].head())
print(df['Penalty_Shootout_Result'].notna().sum(), "matches decided on penalties")
print(df['Extra_Time_Result'].notna().sum(), "matches with extra time")
print(df['Result'].isna().sum(), "results not parsed (residual case)")
# Out:
# 2017
# 0
#      Result Extra_Time_Result Penalty_Shootout_Result
# 1127    4-0              None                    None
# 1128    0-2              None                    None
# 1129    1-2              None                    None
# 1130    0-0              None                    None
# 1131    1-2              None                    None
# 30 matches decided on penalties
# 42 matches with extra time
# 0 results not parsed (residual case)

# %% [markdown]
# ### Cleaning Variables with (%)

# %%
# only columns that have this format
combined_cols = ['Passes_Home', 'Passes_Away'] 

for col in combined_cols:
    extraction = df[col].astype(str).str.extract(r'(\d+)%\((\d+)/\d+\)')
    
    # two new columns from the extraction and to numeric.
    df[f"{col}_Pct"] = pd.to_numeric(extraction[0], errors='coerce')
    df[f"{col}_Successful"] = pd.to_numeric(extraction[1], errors='coerce')

# check the result and drop the original column
print(df[[f"{combined_cols[0]}_Pct", f"{combined_cols[0]}_Successful"]].head())

df = df.drop(columns=combined_cols)
# Out:
#       Passes_Home_Pct  Passes_Home_Successful
# 1127             91.0                   677.0
# 1128             71.0                   205.0
# 1129             75.0                   225.0
# 1130             80.0                   321.0
# 1131             81.0                   420.0

# %%
percentaje_cols = ['Possession_Home', 'Possession_Away', 'Passes_Home_Pct', 'Passes_Away_Pct'] 

for col in percentaje_cols:
    df[col] = df[col].astype(str).str.replace('%', '').astype(float) 

print(df[['Possession_Home', 'Possession_Away']].head())
# Out:
#       Possession_Home  Possession_Away
# 1127             71.0             29.0
# 1128             30.0             70.0
# 1129             43.0             57.0
# 1130             48.0             52.0
# 1131             49.0             51.0

# %% [markdown]
# ## Temporal Filter
#
# We remove the 2026 World Cup matches (which are test data, not training data) and keep only the prior historical data for analysis.

# %%
print(f"Total original rows: {len(df)}")

# only matches before the 2026 World Cup
threshold_date = pd.to_datetime('2026-06-11')
df = df[df['Date'] < threshold_date].copy()

print(f"Rows for analysis: {len(df)}")
# Out:
# Total original rows: 2017
# Rows for analysis: 1945

# %% [markdown]
# ## Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Date                                 0
# Home_Team                            0
# Away_Team                            0
# Result                               0
# Expected_Goals_Home_(xG)           913
# Expected_Goals_Away_(xG)           913
# Possession_Home                    317
# Possession_Away                    317
# Shots_on_Target_Home               316
# Shots_on_Target_Away               316
# Corners_Home                       316
# Corners_Away                       316
# Yellow_Cards_Home                  386
# Yellow_Cards_Away                  386
# Fouls_Home                         369
# Fouls_Away                         369
# Saves_Home                         400
# Saves_Away                         400
# Home_Score                          21
# Away_Score                          22
# Home_Market_Value_Millions_EUR       3
# Away_Market_Value_Millions_EUR       4
# Year                                 0
# Extra_Time_Result                 1903
# Penalty_Shootout_Result           1915
# Passes_Home_Pct                    656
# Passes_Home_Successful             656
# Passes_Away_Pct                    656
# Passes_Away_Successful             656
# dtype: int64

# %% [markdown]
# We use the Possession variable to remove rows with NAs. This is because possession is the most basic match statistic. If this data is missing, we assume there is not enough useful information to model the match and we therefore drop those observations.

# %%
# Columns that MUST be complete
necessary_cols = ['Possession_Away', 'Possession_Home'] 

# dropping rows that have at least one NA in the required columns
df = df.dropna(subset=necessary_cols)

# now we reset the index after dropping rows
df = df.reset_index(drop=True)

print(df.shape)
df.isnull().sum()
# Out:
# (1628, 29)
# Date                                 0
# Home_Team                            0
# Away_Team                            0
# Result                               0
# Expected_Goals_Home_(xG)           596
# Expected_Goals_Away_(xG)           596
# Possession_Home                      0
# Possession_Away                      0
# Shots_on_Target_Home                 0
# Shots_on_Target_Away                 0
# Corners_Home                         0
# Corners_Away                         0
# Yellow_Cards_Home                   71
# Yellow_Cards_Away                   71
# Fouls_Home                          53
# Fouls_Away                          53
# Saves_Home                          84
# Saves_Away                          84
# Home_Score                           7
# Away_Score                           8
# Home_Market_Value_Millions_EUR       0
# Away_Market_Value_Millions_EUR       0
# Year                                 0
# Extra_Time_Result                 1589
# Penalty_Shootout_Result           1600
# Passes_Home_Pct                    339
# Passes_Home_Successful             339
# Passes_Away_Pct                    339
# Passes_Away_Successful             339
# dtype: int64

# %% [markdown]
# # Data Imputation

# %% [markdown]
# To avoid losing too many observations, we impute missing values using IterativeImputer from sklearn.
#
# The parameters are not fully optimised and the goal here is simply to obtain a complete and reasonable dataset, not a perfect one.

# %%
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

# 1. Split the dataset, untouchable columns (text/identifiers) and columns to impute
col_text = ['Date', 'Home_Team', 'Away_Team', 'Result', 'Extra_Time_Result', 'Penalty_Shootout_Result'] 
col_numeric = [col for col in df.columns if col not in col_text]

# 2. Set up the Imputer
# We use RandomForest internally because it captures non-linear relationships in football very well
imputer = IterativeImputer(
    estimator=RandomForestRegressor(n_estimators=50, random_state=42),
    max_iter=10,
    random_state=42,
    min_value=0  # No one can have -2 shots or -0.5 xG
)

# 3. Fit and apply the imputation only on numerical variables
df_imputated = pd.DataFrame(
    imputer.fit_transform(df[col_numeric]), 
    columns=col_numeric, 
    index=df.index
)

# 4. Rejoin the untouched text columns with the cleaned numerical ones
df = pd.concat([df[col_text], df_imputated], axis=1)

print(df.isna().sum())
# Out:
# Date                                 0
# Home_Team                            0
# Away_Team                            0
# Result                               0
# Extra_Time_Result                 1589
# Penalty_Shootout_Result           1600
# Expected_Goals_Home_(xG)             0
# Expected_Goals_Away_(xG)             0
# Possession_Home                      0
# Possession_Away                      0
# Shots_on_Target_Home                 0
# Shots_on_Target_Away                 0
# Corners_Home                         0
# Corners_Away                         0
# Yellow_Cards_Home                    0
# Yellow_Cards_Away                    0
# Fouls_Home                           0
# Fouls_Away                           0
# Saves_Home                           0
# Saves_Away                           0
# Home_Score                           0
# Away_Score                           0
# Home_Market_Value_Millions_EUR       0
# Away_Market_Value_Millions_EUR       0
# Year                                 0
# Passes_Home_Pct                      0
# Passes_Home_Successful               0
# Passes_Away_Pct                      0
# Passes_Away_Successful               0
# dtype: int64
# /Users/pfm20/UNIVERSIDAD/4. CUARTO/1 CUATRI/DATA SCIENCE IN PRACTICE/Football-scrapping-project/venv/lib/python3.9/site-packages/sklearn/impute/_iterative.py:895: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %% [markdown]
# We build variables.

# %%
df[["Goals_Home", "Goals_Away"]] = df["Result"].str.split("-", expand=True)
df["Goals_Home"] = pd.to_numeric(df["Goals_Home"], errors="coerce")
df["Goals_Away"] = pd.to_numeric(df["Goals_Away"], errors="coerce")

# Multi-class target: 1=Home wins, X=Draw, 2=Away wins
df["Result_1X2"] = df.apply(lambda row: "1" if row["Goals_Home"] > row["Goals_Away"] 
                                         else ("X" if row["Goals_Home"] == row["Goals_Away"] else "2"), axis=1)

# Continuous target: goal difference (for regression)
df["Goals_diff"] = df["Goals_Home"] - df["Goals_Away"]
# Binary target: home win (1) or not (0)
df["Home_Win"] = (df["Goals_Home"] > df["Goals_Away"]).astype(int)

print(df['Result_1X2'].value_counts())
print(f"Home win rate: {df['Home_Win'].mean():.2%}")
df.head()
# Out:
# Result_1X2
# 1    705
# 2    526
# X    397
# Name: count, dtype: int64
# Home win rate: 43.30%
#         Date   Home_Team          Away_Team Result Extra_Time_Result  \
# 0 2023-03-23    Portugal      Liechtenstein    4-0              None
# 1 2023-03-23  San Marino  Irlanda del Norte    0-2              None
# 2 2023-03-23  Kazajistán          Eslovenia    1-2              None
# 3 2023-03-23  Eslovaquia         Luxemburgo    0-0              None
# 4 2023-03-23      Italia         Inglaterra    1-2              None
#
#   Penalty_Shootout_Result  Expected_Goals_Home_(xG)  Expected_Goals_Away_(xG)  \
# 0                    None                      4.16                      0.03
# 1                    None                      0.03                      1.79
# 2                    None                      0.63                      1.49
# 3                    None                      1.25                      0.61
# 4                    None                      1.16                      2.07
#
#    Possession_Home  Possession_Away  Shots_on_Target_Home  \
# 0             71.0             29.0                  11.0
# 1             30.0             70.0                   1.0
# 2             43.0             57.0                   2.0
# 3             48.0             52.0                   3.0
# 4             49.0             51.0                   1.0
#
#    Shots_on_Target_Away  Corners_Home  Corners_Away  Yellow_Cards_Home  \
# 0                   1.0          12.0           0.0               0.48
# 1                   4.0           0.0           9.0               0.00
# 2                   6.0           3.0           4.0               2.00
# 3                   2.0           9.0           2.0               0.00
# 4                   4.0           7.0           3.0               3.00
#
#    Yellow_Cards_Away  Fouls_Home  Fouls_Away  Saves_Home  Saves_Away  \
# 0                1.5         5.0         6.0         1.0         7.0
# 1                1.0        16.0         9.0         2.0         1.0
# 2                1.0        17.0        11.0         4.0         1.0
# 3                2.0        11.0        17.0         2.0         3.0
# 4                5.0        13.0         6.0         2.0         0.0
#
#    Home_Score  Away_Score  Home_Market_Value_Millions_EUR  \
# 0     1702.54      859.84                          38.670
# 1      763.15     1396.55                           0.044
# 2     1163.09     1389.06                           0.652
# 3     1425.58     1245.35                           2.300
# 4     1723.56     1774.19                          13.730
#
#    Away_Market_Value_Millions_EUR    Year  Passes_Home_Pct  \
# 0                           0.026  2023.0             91.0
# 1                           3.470  2023.0             71.0
# 2                           4.020  2023.0             75.0
# 3                           0.639  2023.0             80.0
# 4                          52.430  2023.0             81.0
#
#    Passes_Home_Successful  Passes_Away_Pct  Passes_Away_Successful  \
# 0                   677.0             56.0                    91.0
# 1                   205.0             87.0                   582.0
# 2                   225.0             86.0                   408.0
# 3                   321.0             78.0                   334.0
# 4                   420.0             82.0                   318.0
#
#    Goals_Home  Goals_Away Result_1X2  Goals_diff  Home_Win
# 0           4           0          1           4         1
# 1           0           2          2          -2         0
# 2           1           2          2          -1         0
# 3           0           0          X           0         0
# 4           1           2          2          -1         0

# %% [markdown]
# We will build "Share" variables. Essentially, out of the total shots, what percentage belongs to the home team and what percentage to the away team. These variables tend to work very well in sports, as they indicate the offensive power of a team not in absolute terms but relative to the match.

# %%
# Structure: (Home Column Name, Away Column Name, Name for the new metric)
metric_pairs = [
    ('Expected_Goals_Home_(xG)', 'Expected_Goals_Away_(xG)', 'xG'),
    ('Shots_on_Target_Home', 'Shots_on_Target_Away', 'Shots_on_Target'),
    ('Corners_Home', 'Corners_Away', 'Corners'),
    ('Saves_Home', 'Saves_Away', 'Saves'),
    ('Passes_Home_Successful', 'Passes_Away_Successful', 'Passes_Successful'),
    ('Goals_Home', 'Goals_Away', 'Goals'),
    ('Home_Score', 'Away_Score', 'Score'),
    ('Home_Market_Value_Millions_EUR', 'Away_Market_Value_Millions_EUR', 'Market_Value_Millions_EUR')
]

for col_local, col_away, base_name in metric_pairs:
    # 1.Calculate  total volume of the metric in the match
    total_sum = df[col_local] + df[col_away]
    
    # 2.Calculate Home Share
    df[f'{base_name}_Share_Home'] = np.where(
        total_sum > 0,
        df[col_local] / total_sum,
        0.5  # Assign 0.5 when total is 0 (for example 0 goals from both = balanced match)
    )
    
    # 3. The Away Share is mathematically the inverse (1 - Home)
    df[f'{base_name}_Share_Away'] = 1 - df[f'{base_name}_Share_Home']

#sample of the newly generated columns
generated_cols = [f"{t[2]}_Share_Home" for t in metric_pairs]

# Check 
df[['Home_Team', 'Away_Team', 'Result'] + generated_cols].head()
# Out:
#     Home_Team          Away_Team Result  xG_Share_Home  \
# 0    Portugal      Liechtenstein    4-0       0.992840
# 1  San Marino  Irlanda del Norte    0-2       0.016484
# 2  Kazajistán          Eslovenia    1-2       0.297170
# 3  Eslovaquia         Luxemburgo    0-0       0.672043
# 4      Italia         Inglaterra    1-2       0.359133
#
#    Shots_on_Target_Share_Home  Corners_Share_Home  Saves_Share_Home  \
# 0                    0.916667            1.000000          0.125000
# 1                    0.200000            0.000000          0.666667
# 2                    0.250000            0.428571          0.800000
# 3                    0.600000            0.818182          0.400000
# 4                    0.200000            0.700000          1.000000
#
#    Passes_Successful_Share_Home  Goals_Share_Home  Score_Share_Home  \
# 0                      0.881510          1.000000          0.664437
# 1                      0.260483          0.000000          0.353359
# 2                      0.355450          0.333333          0.455729
# 3                      0.490076          0.500000          0.533739
# 4                      0.569106          0.333333          0.492762
#
#    Market_Value_Millions_EUR_Share_Home
# 0                              0.999328
# 1                              0.012521
# 2                              0.139555
# 3                              0.782579
# 4                              0.207527

# %% [markdown]
# ## Raw Statistics Differences (Home - Away)
#
# For the question, the match statistics are our main variables of interest. We create Home − Away differences for each metric so that a positive value indicates a home team advantage.

# %%
metrics_diff = [
    ('Expected_Goals_Home_(xG)', 'Expected_Goals_Away_(xG)', 'xG_diff'),
    ('Possession_Home', 'Possession_Away', 'Possession_diff'),
    ('Shots_on_Target_Home', 'Shots_on_Target_Away', 'Shots_on_Target_diff'),
    ('Corners_Home', 'Corners_Away', 'Corners_diff'),
    ('Passes_Home_Successful', 'Passes_Away_Successful', 'Passes_Successful_diff'),
    ('Passes_Home_Pct', 'Passes_Away_Pct', 'Passes_Pct_diff'),
    ('Yellow_Cards_Home', 'Yellow_Cards_Away', 'Yellow_Cards_diff'),
    ('Fouls_Home', 'Fouls_Away', 'Fouls_diff'),
    ('Saves_Home', 'Saves_Away', 'Saves_diff'),
    ('Home_Score', 'Away_Score', 'Score_diff'),
    ('Home_Market_Value_Millions_EUR', 'Away_Market_Value_Millions_EUR', 'Market_Value_Millions_EUR_diff'),
]

for col_local, col_away, name in metrics_diff:
    if col_local in df.columns and col_away in df.columns:
        df[name] = df[col_local] - df[col_away]
    else:
        print(f'WARNING: column not found for {name}')

cols_diff = [n for _, _, n in metrics_diff if n in df.columns]
print('Difference columns created:', cols_diff)
df[cols_diff].head()
# Out:
# Difference columns created: ['xG_diff', 'Possession_diff', 'Shots_on_Target_diff', 'Corners_diff', 'Passes_Successful_diff', 'Passes_Pct_diff', 'Yellow_Cards_diff', 'Fouls_diff', 'Saves_diff', 'Score_diff', 'Market_Value_Millions_EUR_diff']
#    xG_diff  Possession_diff  Shots_on_Target_diff  Corners_diff  \
# 0     4.13             42.0                  10.0          12.0
# 1    -1.76            -40.0                  -3.0          -9.0
# 2    -0.86            -14.0                  -4.0          -1.0
# 3     0.64             -4.0                   1.0           7.0
# 4    -0.91             -2.0                  -3.0           4.0
#
#    Passes_Successful_diff  Passes_Pct_diff  Yellow_Cards_diff  Fouls_diff  \
# 0                   586.0             35.0              -1.02        -1.0
# 1                  -377.0            -16.0              -1.00         7.0
# 2                  -183.0            -11.0               1.00         6.0
# 3                   -13.0              2.0              -2.00        -6.0
# 4                   102.0             -1.0              -2.00         7.0
#
#    Saves_diff  Score_diff  Market_Value_Millions_EUR_diff
# 0        -6.0      842.70                          38.644
# 1         1.0     -633.40                          -3.426
# 2         3.0     -225.97                          -3.368
# 3        -1.0      180.23                           1.661
# 4         2.0      -50.63                         -38.700

# %% [markdown]
# ## Control Variables: Team Quality
#
# We add variables derived from the FIFA ranking and market value as team quality controls. They allow us to isolate the effect of match performance statistics from the intrinsic level of the teams.

# %%
print(df.shape)
df.tail()
# Out:
# (1628, 61)
#            Date           Home_Team            Away_Team Result  \
# 1623 2026-05-28              Egipto                Rusia    1-0
# 1624 2026-05-28             Irlanda                Catar    1-0
# 1625 2026-05-29           Sudáfrica            Nicaragua    0-0
# 1626 2026-05-29  Bosnia-Herzegovina  Macedonia del Norte    0-0
# 1627 2026-05-29                Irak              Andorra    1-0
#
#      Extra_Time_Result Penalty_Shootout_Result  Expected_Goals_Home_(xG)  \
# 1623              None                    None                    1.1200
# 1624              None                    None                    1.9000
# 1625              None                    None                    2.1800
# 1626              None                    None                    1.5498
# 1627              None                    None                    1.4326
#
#       Expected_Goals_Away_(xG)  Possession_Home  Possession_Away  \
# 1623                    0.5200             54.0             46.0
# 1624                    0.4000             52.0             48.0
# 1625                    0.0700             85.0             15.0
# 1626                    0.7062             66.0             34.0
# 1627                    0.6402             66.0             34.0
#
#       Shots_on_Target_Home  Shots_on_Target_Away  Corners_Home  Corners_Away  \
# 1623                   4.0                   1.0           5.0           6.0
# 1624                   3.0                   1.0           7.0           3.0
# 1625                   6.0                   0.0           6.0           1.0
# 1626                   4.0                   2.0           2.0           1.0
# 1627                   3.0                   3.0           3.0           2.0
#
#       Yellow_Cards_Home  Yellow_Cards_Away  Fouls_Home  Fouls_Away  \
# 1623               1.00                2.0       13.00       19.00
# 1624               0.88                2.6        9.00       16.00
# 1625               0.00                2.0        8.00       10.00
# 1626               0.00                1.0       11.00       21.00
# 1627               0.00                3.0       11.96       15.26
#
#       Saves_Home  Saves_Away  Home_Score  Away_Score  \
# 1623        1.00        3.00     1563.24     1525.60
# 1624        1.00        2.00     1436.63     1454.96
# 1625        0.00        7.00     1429.73     1115.13
# 1626        1.16        2.42     1385.84     1372.04
# 1627        2.24        1.76     1447.14      945.34
#
#       Home_Market_Value_Millions_EUR  Away_Market_Value_Millions_EUR    Year  \
# 1623                           4.480                           7.350  2026.0
# 1624                           5.440                           0.766  2026.0
# 1625                           1.890                           0.172  2026.0
# 1626                           5.630                           1.380  2026.0
# 1627                           0.815                           0.137  2026.0
#
#       Passes_Home_Pct  Passes_Home_Successful  Passes_Away_Pct  \
# 1623             86.0                  402.00            85.00
# 1624             87.0                  392.00            88.00
# 1625             92.0                  616.00            56.00
# 1626             92.0                  621.00            79.00
# 1627             86.3                  459.26            71.18
#
#       Passes_Away_Successful  Goals_Home  Goals_Away Result_1X2  Goals_diff  \
# 1623                  334.00           1           0          1           1
# 1624                  358.00           1           0          1           1
# 1625                   65.00           0           0          X           0
# 1626                  257.00           0           0          X           0
# 1627                  198.08           1           0          1           1
#
#       Home_Win  xG_Share_Home  xG_Share_Away  Shots_on_Target_Share_Home  \
# 1623         1       0.682927       0.317073                    0.800000
# 1624         1       0.826087       0.173913                    0.750000
# 1625         0       0.968889       0.031111                    1.000000
# 1626         0       0.686968       0.313032                    0.666667
# 1627         1       0.691142       0.308858                    0.500000
#
#       Shots_on_Target_Share_Away  Corners_Share_Home  Corners_Share_Away  \
# 1623                    0.200000            0.454545            0.545455
# 1624                    0.250000            0.700000            0.300000
# 1625                    0.000000            0.857143            0.142857
# 1626                    0.333333            0.666667            0.333333
# 1627                    0.500000            0.600000            0.400000
#
#       Saves_Share_Home  Saves_Share_Away  Passes_Successful_Share_Home  \
# 1623          0.250000          0.750000                      0.546196
# 1624          0.333333          0.666667                      0.522667
# 1625          0.000000          1.000000                      0.904552
# 1626          0.324022          0.675978                      0.707289
# 1627          0.560000          0.440000                      0.698664
#
#       Passes_Successful_Share_Away  Goals_Share_Home  Goals_Share_Away  \
# 1623                      0.453804               1.0               0.0
# 1624                      0.477333               1.0               0.0
# 1625                      0.095448               0.5               0.5
# 1626                      0.292711               0.5               0.5
# 1627                      0.301336               1.0               0.0
#
#       Score_Share_Home  Score_Share_Away  \
# 1623          0.506093          0.493907
# 1624          0.496830          0.503170
# 1625          0.561811          0.438189
# 1626          0.502502          0.497498
# 1627          0.604870          0.395130
#
#       Market_Value_Millions_EUR_Share_Home  \
# 1623                              0.378698
# 1624                              0.876571
# 1625                              0.916586
# 1626                              0.803138
# 1627                              0.856092
#
#       Market_Value_Millions_EUR_Share_Away  xG_diff  Possession_diff  \
# 1623                              0.621302   0.6000              8.0
# 1624                              0.123429   1.5000              4.0
# 1625                              0.083414   2.1100             70.0
# 1626                              0.196862   0.8436             32.0
# 1627                              0.143908   0.7924             32.0
#
#       Shots_on_Target_diff  Corners_diff  Passes_Successful_diff  \
# 1623                   3.0          -1.0                   68.00
# 1624                   2.0           4.0                   34.00
# 1625                   6.0           5.0                  551.00
# 1626                   2.0           1.0                  364.00
# 1627                   0.0           1.0                  261.18
#
#       Passes_Pct_diff  Yellow_Cards_diff  Fouls_diff  Saves_diff  Score_diff  \
# 1623             1.00              -1.00        -6.0       -2.00       37.64
# 1624            -1.00              -1.72        -7.0       -1.00      -18.33
# 1625            36.00              -2.00        -2.0       -7.00      314.60
# 1626            13.00              -1.00       -10.0       -1.26       13.80
# 1627            15.12              -3.00        -3.3        0.48      501.80
#
#       Market_Value_Millions_EUR_diff
# 1623                          -2.870
# 1624                           4.674
# 1625                           1.718
# 1626                           4.250
# 1627                           0.678

# %%
print(df['Home_Score'].describe())
print(df['Away_Score'].describe())
# Out:
# count    1628.000000
# mean     1354.878901
# std       241.880232
# min       726.030000
# 25%      1168.485000
# 50%      1362.670000
# 75%      1518.902500
# max      1886.160000
# Name: Home_Score, dtype: float64
# count    1628.000000
# mean     1341.972401
# std       237.784574
# min       727.950000
# 25%      1165.012500
# 50%      1345.040000
# 75%      1503.417500
# max      1886.160000
# Name: Away_Score, dtype: float64

# %%
# FIFA points difference
df['Actual_Score_diff'] = df['Home_Score'] - df['Away_Score']

# Implicit ELO based on FIFA ranking points
df['Prob_Implicit_ELO'] = 1 / (1 + 10 ** (-df['Actual_Score_diff'] / 400))

# Tiers based on FIFA points
# Tiers based on quantiles of the actual distribution (all teams, home+away)
all_points = pd.concat([df['Home_Score'], df['Away_Score']])
q25, q50, q75 = all_points.quantile([0.25, 0.5, 0.75])

print(f"Q25: {q25:.0f}, Q50: {q50:.0f}, Q75: {q75:.0f}")

def asign_tier(points):
    if points >= q75: return 1
    elif points >= q50: return 2
    elif points >= q25: return 3
    else: return 4

df['diff_Tier'] = df['Home_Score'].apply(asign_tier) - df['Away_Score'].apply(asign_tier)
# Out:
# Q25: 1166, Q50: 1353, Q75: 1513

# %% [markdown]
# ## Multicollinearity
#
# We have created many variables, often derived from the same source variables, so there is a risk of collinearity. Although the models we will use can handle this, we will remove highly correlated variables to clean up our feature set, since the sample is relatively small. This will also give us a more interpretable model and a dataset that could be used with other models (e.g. regression).

# %%
exclude = [
    'Date', 'Home_Team', 'Away_Team', 'Result', 'Extra_Time_Result', 'Penalty_Shootout_Result', 'Result_1X2',
    'Goals_Home', 'Goals_Away', 'Goals_Diff', 'Home_Win', 'Prob_Implicit_ELO'
]
covariables = [x for x in df.columns if x not in exclude and df[x].dtype != 'object']

corr_matrix = df[covariables].corr().abs()
threshold = 0.8
correlated_pairs = []

for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if corr_matrix.iloc[i, j] > threshold:
            correlated_pairs.append((
                corr_matrix.columns[i],
                corr_matrix.columns[j],
                corr_matrix.iloc[i, j]
            ))

print(f"Pairs with correlation > {threshold}: {len(correlated_pairs)}")
for col_i, col_j, corr in sorted(correlated_pairs, key=lambda x: -x[2]):
    print(f"  {col_i} <-> {col_j}: {corr:.3f}")
# Out:
# Pairs with correlation > 0.8: 97
#   Saves_Share_Away <-> Saves_Share_Home: 1.000
#   Shots_on_Target_Share_Away <-> Shots_on_Target_Share_Home: 1.000
#   xG_Share_Away <-> xG_Share_Home: 1.000
#   Corners_Share_Away <-> Corners_Share_Home: 1.000
#   Goals_Share_Away <-> Goals_Share_Home: 1.000
#   Actual_Score_diff <-> Score_diff: 1.000
#   Market_Value_Millions_EUR_Share_Away <-> Market_Value_Millions_EUR_Share_Home: 1.000
#   Passes_Successful_Share_Away <-> Passes_Successful_Share_Home: 1.000
#   Score_Share_Away <-> Score_Share_Home: 1.000
#   Possession_diff <-> Possession_Home: 1.000
#   Possession_diff <-> Possession_Away: 1.000
#   Possession_Away <-> Possession_Home: 1.000
#   Score_diff <-> Score_Share_Away: 0.992
#   Actual_Score_diff <-> Score_Share_Away: 0.992
#   Score_diff <-> Score_Share_Home: 0.992
#   Actual_Score_diff <-> Score_Share_Home: 0.992
#   Passes_Successful_diff <-> Passes_Successful_Share_Away: 0.986
#   Passes_Successful_diff <-> Passes_Successful_Share_Home: 0.986
#   Passes_Successful_Share_Home <-> Possession_Home: 0.984
#   Passes_Successful_Share_Away <-> Possession_Home: 0.984
#   Possession_diff <-> Passes_Successful_Share_Home: 0.984
#   Possession_diff <-> Passes_Successful_Share_Away: 0.984
#   Passes_Successful_Share_Home <-> Possession_Away: 0.984
#   Passes_Successful_Share_Away <-> Possession_Away: 0.984
#   Passes_Successful_diff <-> Possession_Home: 0.978
#   Passes_Successful_diff <-> Possession_diff: 0.978
#   Passes_Successful_diff <-> Possession_Away: 0.978
#   Passes_Pct_diff <-> Passes_Successful_Share_Home: 0.940
#   Passes_Pct_diff <-> Passes_Successful_Share_Away: 0.940
#   xG_diff <-> xG_Share_Home: 0.924
#   xG_diff <-> xG_Share_Away: 0.924
#   diff_Tier <-> Score_diff: 0.920
#   diff_Tier <-> Actual_Score_diff: 0.920
#   Corners_diff <-> Corners_Share_Away: 0.917
#   Corners_diff <-> Corners_Share_Home: 0.917
#   Passes_Pct_diff <-> Possession_Home: 0.917
#   Passes_Pct_diff <-> Possession_diff: 0.917
#   Passes_Pct_diff <-> Possession_Away: 0.917
#   Passes_Pct_diff <-> Passes_Successful_diff: 0.912
#   Shots_on_Target_diff <-> Shots_on_Target_Share_Home: 0.907
#   Shots_on_Target_diff <-> Shots_on_Target_Share_Away: 0.907
#   diff_Tier <-> Score_Share_Away: 0.905
#   diff_Tier <-> Score_Share_Home: 0.905
#   Saves_diff <-> Shots_on_Target_diff: 0.900
#   Passes_Successful_diff <-> Passes_Home_Successful: 0.900
#   Passes_Successful_diff <-> Passes_Away_Successful: 0.889
#   Passes_Successful_Share_Home <-> Passes_Away_Successful: 0.889
#   Passes_Successful_Share_Away <-> Passes_Away_Successful: 0.889
#   Saves_Home <-> Shots_on_Target_Away: 0.884
#   Passes_Successful_Share_Home <-> Passes_Home_Successful: 0.876
#   Passes_Successful_Share_Away <-> Passes_Home_Successful: 0.876
#   Passes_Away_Successful <-> Possession_Away: 0.876
#   Possession_diff <-> Passes_Away_Successful: 0.876
#   Passes_Away_Successful <-> Possession_Home: 0.876
#   Passes_Home_Successful <-> Possession_Home: 0.873
#   Possession_diff <-> Passes_Home_Successful: 0.873
#   Passes_Home_Successful <-> Possession_Away: 0.873
#   Saves_Away <-> Shots_on_Target_Home: 0.873
#   Saves_diff <-> Saves_Share_Home: 0.873
#   Saves_diff <-> Saves_Share_Away: 0.873
#   Shots_on_Target_diff <-> xG_diff: 0.872
#   xG_diff <-> Expected_Goals_Home_(xG): 0.862
#   Saves_Share_Away <-> Shots_on_Target_Share_Home: 0.858
#   Saves_Share_Home <-> Shots_on_Target_Share_Away: 0.858
#   Saves_Share_Home <-> Shots_on_Target_Share_Home: 0.858
#   Saves_Share_Away <-> Shots_on_Target_Share_Away: 0.858
#   Corners_diff <-> Corners_Home: 0.854
#   Shots_on_Target_Share_Home <-> xG_Share_Away: 0.850
#   Shots_on_Target_Share_Home <-> xG_Share_Home: 0.850
#   Shots_on_Target_Share_Away <-> xG_Share_Away: 0.850
#   Shots_on_Target_Share_Away <-> xG_Share_Home: 0.850
#   Score_diff <-> Market_Value_Millions_EUR_Share_Away: 0.841
#   Actual_Score_diff <-> Market_Value_Millions_EUR_Share_Away: 0.841
#   Score_diff <-> Market_Value_Millions_EUR_Share_Home: 0.841
#   Actual_Score_diff <-> Market_Value_Millions_EUR_Share_Home: 0.841
#   Shots_on_Target_diff <-> Shots_on_Target_Home: 0.841
#   Shots_on_Target_diff <-> xG_Share_Away: 0.833
#   Shots_on_Target_diff <-> xG_Share_Home: 0.833
#   Passes_Pct_diff <-> Passes_Away_Successful: 0.832
#   Market_Value_Millions_EUR_Share_Home <-> Score_Share_Away: 0.832
#   Market_Value_Millions_EUR_Share_Away <-> Score_Share_Away: 0.832
#   Market_Value_Millions_EUR_Share_Home <-> Score_Share_Home: 0.832
#   Market_Value_Millions_EUR_Share_Away <-> Score_Share_Home: 0.832
#   Goals_Share_Away <-> Goals_diff: 0.828
#   Goals_Share_Home <-> Goals_diff: 0.828
#   Shots_on_Target_Home <-> Expected_Goals_Home_(xG): 0.822
#   Saves_diff <-> Shots_on_Target_Share_Away: 0.818
#   Saves_diff <-> Shots_on_Target_Share_Home: 0.818
#   Passes_Home_Successful <-> Passes_Home_Pct: 0.817
#   Shots_on_Target_Away <-> Expected_Goals_Away_(xG): 0.811
#   Passes_Away_Successful <-> Passes_Away_Pct: 0.809
#   xG_diff <-> Expected_Goals_Away_(xG): 0.808
#   xG_Share_Home <-> Expected_Goals_Away_(xG): 0.805
#   xG_Share_Away <-> Expected_Goals_Away_(xG): 0.805
#   Corners_diff <-> Corners_Away: 0.804
#   Passes_Pct_diff <-> Passes_Away_Pct: 0.801
#   Passes_Pct_diff <-> Passes_Home_Successful: 0.801

# %%
df_pares = pd.DataFrame(correlated_pairs, columns=['var_1', 'var_2', 'corr']).sort_values('corr', ascending=False)
df_pares
# Out:
#                          var_1                       var_2      corr
# 24            Saves_Share_Away            Saves_Share_Home  1.000000
# 18  Shots_on_Target_Share_Away  Shots_on_Target_Share_Home  1.000000
# 13               xG_Share_Away               xG_Share_Home  1.000000
# 92           Actual_Score_diff                  Score_diff  1.000000
# 36            Goals_Share_Away            Goals_Share_Home  1.000000
# ..                         ...                         ...       ...
# 11               xG_Share_Home    Expected_Goals_Away_(xG)  0.805421
# 12               xG_Share_Away    Expected_Goals_Away_(xG)  0.805421
# 60                Corners_diff                Corners_Away  0.804278
# 73             Passes_Pct_diff             Passes_Away_Pct  0.801437
# 72             Passes_Pct_diff      Passes_Home_Successful  0.801153
#
# [97 rows x 3 columns]

# %%
print(df.shape)
# Out:
# (1628, 64)

# %% [markdown]
# ## Save Datasets

# %%
print(df.shape)
df.head()
# Out:
# (1628, 64)
#         Date   Home_Team          Away_Team Result Extra_Time_Result  \
# 0 2023-03-23    Portugal      Liechtenstein    4-0              None
# 1 2023-03-23  San Marino  Irlanda del Norte    0-2              None
# 2 2023-03-23  Kazajistán          Eslovenia    1-2              None
# 3 2023-03-23  Eslovaquia         Luxemburgo    0-0              None
# 4 2023-03-23      Italia         Inglaterra    1-2              None
#
#   Penalty_Shootout_Result  Expected_Goals_Home_(xG)  Expected_Goals_Away_(xG)  \
# 0                    None                      4.16                      0.03
# 1                    None                      0.03                      1.79
# 2                    None                      0.63                      1.49
# 3                    None                      1.25                      0.61
# 4                    None                      1.16                      2.07
#
#    Possession_Home  Possession_Away  Shots_on_Target_Home  \
# 0             71.0             29.0                  11.0
# 1             30.0             70.0                   1.0
# 2             43.0             57.0                   2.0
# 3             48.0             52.0                   3.0
# 4             49.0             51.0                   1.0
#
#    Shots_on_Target_Away  Corners_Home  Corners_Away  Yellow_Cards_Home  \
# 0                   1.0          12.0           0.0               0.48
# 1                   4.0           0.0           9.0               0.00
# 2                   6.0           3.0           4.0               2.00
# 3                   2.0           9.0           2.0               0.00
# 4                   4.0           7.0           3.0               3.00
#
#    Yellow_Cards_Away  Fouls_Home  Fouls_Away  Saves_Home  Saves_Away  \
# 0                1.5         5.0         6.0         1.0         7.0
# 1                1.0        16.0         9.0         2.0         1.0
# 2                1.0        17.0        11.0         4.0         1.0
# 3                2.0        11.0        17.0         2.0         3.0
# 4                5.0        13.0         6.0         2.0         0.0
#
#    Home_Score  Away_Score  Home_Market_Value_Millions_EUR  \
# 0     1702.54      859.84                          38.670
# 1      763.15     1396.55                           0.044
# 2     1163.09     1389.06                           0.652
# 3     1425.58     1245.35                           2.300
# 4     1723.56     1774.19                          13.730
#
#    Away_Market_Value_Millions_EUR    Year  Passes_Home_Pct  \
# 0                           0.026  2023.0             91.0
# 1                           3.470  2023.0             71.0
# 2                           4.020  2023.0             75.0
# 3                           0.639  2023.0             80.0
# 4                          52.430  2023.0             81.0
#
#    Passes_Home_Successful  Passes_Away_Pct  Passes_Away_Successful  \
# 0                   677.0             56.0                    91.0
# 1                   205.0             87.0                   582.0
# 2                   225.0             86.0                   408.0
# 3                   321.0             78.0                   334.0
# 4                   420.0             82.0                   318.0
#
#    Goals_Home  Goals_Away Result_1X2  Goals_diff  Home_Win  xG_Share_Home  \
# 0           4           0          1           4         1       0.992840
# 1           0           2          2          -2         0       0.016484
# 2           1           2          2          -1         0       0.297170
# 3           0           0          X           0         0       0.672043
# 4           1           2          2          -1         0       0.359133
#
#    xG_Share_Away  Shots_on_Target_Share_Home  Shots_on_Target_Share_Away  \
# 0       0.007160                    0.916667                    0.083333
# 1       0.983516                    0.200000                    0.800000
# 2       0.702830                    0.250000                    0.750000
# 3       0.327957                    0.600000                    0.400000
# 4       0.640867                    0.200000                    0.800000
#
#    Corners_Share_Home  Corners_Share_Away  Saves_Share_Home  Saves_Share_Away  \
# 0            1.000000            0.000000          0.125000          0.875000
# 1            0.000000            1.000000          0.666667          0.333333
# 2            0.428571            0.571429          0.800000          0.200000
# 3            0.818182            0.181818          0.400000          0.600000
# 4            0.700000            0.300000          1.000000          0.000000
#
#    Passes_Successful_Share_Home  Passes_Successful_Share_Away  \
# 0                      0.881510                      0.118490
# 1                      0.260483                      0.739517
# 2                      0.355450                      0.644550
# 3                      0.490076                      0.509924
# 4                      0.569106                      0.430894
#
#    Goals_Share_Home  Goals_Share_Away  Score_Share_Home  Score_Share_Away  \
# 0          1.000000          0.000000          0.664437          0.335563
# 1          0.000000          1.000000          0.353359          0.646641
# 2          0.333333          0.666667          0.455729          0.544271
# 3          0.500000          0.500000          0.533739          0.466261
# 4          0.333333          0.666667          0.492762          0.507238
#
#    Market_Value_Millions_EUR_Share_Home  Market_Value_Millions_EUR_Share_Away  \
# 0                              0.999328                              0.000672
# 1                              0.012521                              0.987479
# 2                              0.139555                              0.860445
# 3                              0.782579                              0.217421
# 4                              0.207527                              0.792473
#
#    xG_diff  Possession_diff  Shots_on_Target_diff  Corners_diff  \
# 0     4.13             42.0                  10.0          12.0
# 1    -1.76            -40.0                  -3.0          -9.0
# 2    -0.86            -14.0                  -4.0          -1.0
# 3     0.64             -4.0                   1.0           7.0
# 4    -0.91             -2.0                  -3.0           4.0
#
#    Passes_Successful_diff  Passes_Pct_diff  Yellow_Cards_diff  Fouls_diff  \
# 0                   586.0             35.0              -1.02        -1.0
# 1                  -377.0            -16.0              -1.00         7.0
# 2                  -183.0            -11.0               1.00         6.0
# 3                   -13.0              2.0              -2.00        -6.0
# 4                   102.0             -1.0              -2.00         7.0
#
#    Saves_diff  Score_diff  Market_Value_Millions_EUR_diff  Actual_Score_diff  \
# 0        -6.0      842.70                          38.644             842.70
# 1         1.0     -633.40                          -3.426            -633.40
# 2         3.0     -225.97                          -3.368            -225.97
# 3        -1.0      180.23                           1.661             180.23
# 4         2.0      -50.63                         -38.700             -50.63
#
#    Prob_Implicit_ELO  diff_Tier
# 0           0.992240         -3
# 1           0.025428          2
# 2           0.214032          2
# 3           0.738365         -1
# 4           0.427649          0

# %%
# Final dataset columns
print(df.columns.tolist())
# Out:
# ['Date', 'Home_Team', 'Away_Team', 'Result', 'Extra_Time_Result', 'Penalty_Shootout_Result', 'Expected_Goals_Home_(xG)', 'Expected_Goals_Away_(xG)', 'Possession_Home', 'Possession_Away', 'Shots_on_Target_Home', 'Shots_on_Target_Away', 'Corners_Home', 'Corners_Away', 'Yellow_Cards_Home', 'Yellow_Cards_Away', 'Fouls_Home', 'Fouls_Away', 'Saves_Home', 'Saves_Away', 'Home_Score', 'Away_Score', 'Home_Market_Value_Millions_EUR', 'Away_Market_Value_Millions_EUR', 'Year', 'Passes_Home_Pct', 'Passes_Home_Successful', 'Passes_Away_Pct', 'Passes_Away_Successful', 'Goals_Home', 'Goals_Away', 'Result_1X2', 'Goals_diff', 'Home_Win', 'xG_Share_Home', 'xG_Share_Away', 'Shots_on_Target_Share_Home', 'Shots_on_Target_Share_Away', 'Corners_Share_Home', 'Corners_Share_Away', 'Saves_Share_Home', 'Saves_Share_Away', 'Passes_Successful_Share_Home', 'Passes_Successful_Share_Away', 'Goals_Share_Home', 'Goals_Share_Away', 'Score_Share_Home', 'Score_Share_Away', 'Market_Value_Millions_EUR_Share_Home', 'Market_Value_Millions_EUR_Share_Away', 'xG_diff', 'Possession_diff', 'Shots_on_Target_diff', 'Corners_diff', 'Passes_Successful_diff', 'Passes_Pct_diff', 'Yellow_Cards_diff', 'Fouls_diff', 'Saves_diff', 'Score_diff', 'Market_Value_Millions_EUR_diff', 'Actual_Score_diff', 'Prob_Implicit_ELO', 'diff_Tier']

# %%
# Available targets for analysis
print('Targets:')
print('  Result_1X2:', df['Result_1X2'].value_counts().to_dict())
print('  Home win mean:', df['Home_Win'].mean().round(3))
print('  Goals_diff mean:', df['Goals_diff'].mean().round(3))
# Out:
# Targets:
#   Result_1X2: {'1': 705, '2': 526, 'X': 397}
#   Home win mean: 0.433
#   Goals_diff mean: 0.364

# %%
print(f"Dataset saved: {df.shape[0]} matches, {df.shape[1]} columns")
# df.to_csv('./data/matches_cleaned.csv', index=False)
# Out:
# Dataset saved: 1628 matches, 64 columns

# %%
# Summary of features available for EDA
features_performance = [c for c in df.columns if any(x in c for x in 
    ['xG', 'Possesion', 'Shots', 'Corner', 'Passes', 'Cards', 'Fouls', 'Saves', '_diff', '_Share'])]
features_control = ['FIFA_diff', 'Market_Value_diff', 'Actual_Score_diff', 'Prob_Implicit_ELO', 'diff_Tier']
targets = ['Result_1X2', 'Home_Win', 'Goals_diff']

print(f'Match performance features: {len(features_performance)}')
print(features_performance)
print(f'\nTeam quality controls: {[f for f in features_control if f in df.columns]}')
print(f'\nTargets: {targets}')
# Out:
# Match performance features: 45
# ['Expected_Goals_Home_(xG)', 'Expected_Goals_Away_(xG)', 'Shots_on_Target_Home', 'Shots_on_Target_Away', 'Corners_Home', 'Corners_Away', 'Yellow_Cards_Home', 'Yellow_Cards_Away', 'Fouls_Home', 'Fouls_Away', 'Saves_Home', 'Saves_Away', 'Passes_Home_Pct', 'Passes_Home_Successful', 'Passes_Away_Pct', 'Passes_Away_Successful', 'Goals_diff', 'xG_Share_Home', 'xG_Share_Away', 'Shots_on_Target_Share_Home', 'Shots_on_Target_Share_Away', 'Corners_Share_Home', 'Corners_Share_Away', 'Saves_Share_Home', 'Saves_Share_Away', 'Passes_Successful_Share_Home', 'Passes_Successful_Share_Away', 'Goals_Share_Home', 'Goals_Share_Away', 'Score_Share_Home', 'Score_Share_Away', 'Market_Value_Millions_EUR_Share_Home', 'Market_Value_Millions_EUR_Share_Away', 'xG_diff', 'Possession_diff', 'Shots_on_Target_diff', 'Corners_diff', 'Passes_Successful_diff', 'Passes_Pct_diff', 'Yellow_Cards_diff', 'Fouls_diff', 'Saves_diff', 'Score_diff', 'Market_Value_Millions_EUR_diff', 'Actual_Score_diff']
#
# Team quality controls: ['Actual_Score_diff', 'Prob_Implicit_ELO', 'diff_Tier']
#
# Targets: ['Result_1X2', 'Home_Win', 'Goals_diff']

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# Figure 4: Match outcome (1X2)
counts_1x2 = df['Result_1X2'].value_counts().reindex(['1', 'X', '2'])
bars = axes[0].bar(range(3), counts_1x2.values,
                   color='white', edgecolor='black', linewidth=1)
for bar, h in zip(bars, ['///', '...', 'xxx']):
    bar.set_hatch(h)
axes[0].set_xticks(range(3))
axes[0].set_xticklabels(['Home win\n(1)', 'Draw\n(X)', 'Away win\n(2)'])
axes[0].set_ylabel('Matches')
axes[0].set_title('Figure 4. Match outcome (1X2)', fontsize=11)

# Figure 5: Home win (binary)
counts_win = df['Home_Win'].value_counts().reindex([0, 1])
bars = axes[1].bar(range(2), counts_win.values,
                   color='white', edgecolor='black', linewidth=1)
for bar, h in zip(bars, ['...', '///']):
    bar.set_hatch(h)
axes[1].set_xticks(range(2))
axes[1].set_xticklabels(['No (0)', 'Yes (1)'])
axes[1].set_xlabel('Home team won')
axes[1].set_ylabel('Matches')
axes[1].set_title('Figure 5. Home win (binary)', fontsize=11)

# Figure 6: Goal difference
axes[2].hist(df['Goals_diff'].dropna(), bins=20,
             color='white', edgecolor='black', linewidth=0.8, hatch='///')
axes[2].axvline(0, color='black', linestyle='--', linewidth=1.2, label='Draw (0)')
axes[2].set_xlabel('Goal difference (Home − Away)')
axes[2].set_ylabel('Frequency')
axes[2].set_title('Figure 6. Goal difference', fontsize=11)
axes[2].legend(fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # Exploratory Data Analysis
#
# The following analysis addresses the research question: **Which match performance statistics are the strongest predictors of football match outcomes?**
#
# All figures use patterns (hatching, markers) to remain readable in black & white. Figures are numbered sequentially; tables are rounded to 3 decimal places.

# %% [markdown]
# ### Table 2. Mean performance statistics by match outcome
#
# Average values of key metric differences (Home − Away) grouped by match outcome (1 = home win, X = draw, 2 = away win). Positive values indicate a home team advantage.

# %%
# --- Table 2: Mean stats by outcome ---
stats_cols = ['xG_diff', 'Possession_diff', 'Shots_on_Target_diff',
              'Corners_diff', 'Passes_Successful_diff', 'Saves_diff']
stats_cols = [c for c in stats_cols if c in df.columns]

table = df.groupby('Result_1X2')[stats_cols].mean().round(3)
table.index.name = 'Outcome'
table.index = table.index.map({'1': '1 (Home win)', 'X': 'X (Draw)', '2': '2 (Away win)'})
table.columns = [c.replace('_diff', '') for c in table.columns]
print('Table 2. Mean performance metric differences by match outcome')
print(table.to_string())

print('\nMatch counts per outcome:')
print(df['Result_1X2'].map({'1': '1 (Home win)', 'X': 'X (Draw)', '2': '2 (Away win)'}).value_counts().sort_index().to_string())
# Out:
# Table 2. Mean performance metric differences by match outcome
#                  xG  Possession  Shots_on_Target  Corners  Passes_Successful  Saves
# Outcome
# 1 (Home win)  1.303      14.637            3.950    2.668            146.730 -1.699
# 2 (Away win) -0.942      -9.445           -2.833   -0.859            -97.803  0.977
# X (Draw)      0.141       2.131            0.481    0.542             14.767 -0.495
#
# Match counts per outcome:
# Result_1X2
# 1 (Home win)    705
# 2 (Away win)    526
# X (Draw)        397

# %% [markdown]
# ### Figure 7. Distribution of key performance statistics by match outcome
#
# Box plots of performance metric differences (Local − Visitante) grouped by match outcome. A systematic shift across groups indicates predictive power. The dashed line marks zero (parity between teams).

# %%
stats_plot = [
    ('xG_diff',           'xG difference'),
    ('Possession_diff',      'Possession difference'),
    ('Shots_on_Target_diff','Shots on target diff.'),
    ('Corners_diff',      'Corners difference'),
]
stats_plot = [(c, l) for c, l in stats_plot if c in df.columns]

outcomes = ['1', 'X', '2']
tick_labels = ['Home win\n(1)', 'Draw\n(X)', 'Away win\n(2)']
hatches = ['///', '...', 'xxx']
facecolors = ['white', 'lightgray', 'dimgray']

fig, axes = plt.subplots(1, len(stats_plot), figsize=(13, 5))
if len(stats_plot) == 1:
    axes = [axes]

for ax, (col, ylabel) in zip(axes, stats_plot):
    data_groups = [df.loc[df['Result_1X2'] == o, col].dropna() for o in outcomes]
    bp = ax.boxplot(data_groups, patch_artist=True, label=tick_labels,
                    medianprops=dict(color='black', linewidth=2),
                    flierprops=dict(marker='.', color='black', markersize=3))
    for patch, hatch, fc in zip(bp['boxes'], hatches, facecolors):
        patch.set_facecolor(fc)
        patch.set_hatch(hatch)
    ax.axhline(0, color='black', linestyle='--', linewidth=0.8, alpha=0.6)
    ax.set_ylabel(ylabel, fontsize=10)
    ax.tick_params(axis='x', labelsize=9)

fig.suptitle('Figure 7. Key performance statistics by match outcome', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Figure 8. Correlation of match statistics with home team victory
#
# Point-biserial correlation between each performance metric difference and the binary outcome Win\_Home(1 = home win, 0 = otherwise). Bars are ordered by absolute correlation, forward hatching (///) indicates positive association, back hatching (\\\\\\) indicates negative.

# %%
diff_cols = [c for c in df.columns if c.endswith('_diff')
             and c not in ('Goals_diff',) and df[c].dtype != object]
corrs = (df[diff_cols + ['Home_Win']]
         .corr(numeric_only=True)['Home_Win']
         .drop('Home_Win')
         .dropna()
         .sort_values())

fig, ax = plt.subplots(figsize=(8, max(4, len(corrs) * 0.4)))
bars = ax.barh(range(len(corrs)), corrs.values,
               color='white', edgecolor='black', linewidth=0.8)
for bar, val in zip(bars, corrs.values):
    bar.set_hatch('///' if val >= 0 else '\\\\\\')

ax.axvline(0, color='black', linewidth=1)
ax.set_yticks(range(len(corrs)))
ax.set_yticklabels([c.replace('_diff', '').replace('_', ' ') for c in corrs.index], fontsize=9)
ax.set_xlabel('Correlation with home win (Home_Win)', fontsize=11)
ax.set_title('Figure 8. Correlation of match statistics with home team victory', fontsize=12)
plt.tight_layout()
plt.show()

print('Top 5 predictors (absolute correlation):')
print(corrs.abs().sort_values(ascending=False).head(5).round(3).to_string())
# Out:
# Top 5 predictors (absolute correlation):
# xG_diff                   0.576
# Shots_on_Target_diff      0.576
# Score_diff                0.560
# Actual_Score_diff         0.560
# Passes_Successful_diff    0.388

# %% [markdown]
# ### Figure 9. Expected goals difference vs. goal difference
#
# Scatter plot of xG difference against goal difference by match outcome. xG measures the quality of chances created; strong alignment with actual goals validates its use as a predictor. Outcomes are differentiated by marker shape to maintain B&W readability.

# %%
if 'xG_diff' in df.columns and 'Goals_diff' in df.columns:
    markers_map = {'1': 'o', 'X': 's', '2': '^'}
    labels_map  = {'1': 'Home win (1)', 'X': 'Draw (X)', '2': 'Away win (2)'}

    fig, ax = plt.subplots(figsize=(7, 6))
    for outcome, marker in markers_map.items():
        sub = df[df['Result_1X2'] == outcome].dropna(subset=['xG_diff', 'Goals_diff'])
        ax.scatter(sub['xG_diff'], sub['Goals_diff'],
                   marker=marker, s=25, alpha=0.55,
                   facecolors='none', edgecolors='black',
                   label=labels_map[outcome], linewidths=0.8)

    ax.axhline(0, color='black', linestyle='--', linewidth=0.8, alpha=0.5)
    ax.axvline(0, color='black', linestyle='--', linewidth=0.8, alpha=0.5)
    ax.set_xlabel('xG difference (Local − Visitante)', fontsize=11)
    ax.set_ylabel('Goal difference (Local − Visitante)', fontsize=11)
    ax.set_title('Figure 9. xG difference vs. goal difference by match outcome', fontsize=12)
    ax.legend(fontsize=10)
    plt.tight_layout()
    plt.show()

    r = df[['xG_diff', 'Goals_diff']].corr().iloc[0, 1]
    print(f'Pearson r (xG_diff vs Goals_diff): {r:.3f}')
# Out:
# Pearson r (xG_diff vs Goals_diff): 0.782

# %% [markdown]
# ### Figure 10. Home win rate by xG difference quartile
#
# Home win rate across quartiles of xG difference (Q1 = largest away advantage, Q4 = largest home advantage). A monotone increase across quartiles would confirm that xG is a reliable predictor of match outcome.

# %%
if 'xG_diff' in df.columns:
    df_q = df[['xG_diff', 'Home_Win']].dropna().copy()
    df_q['xG_quartile'] = pd.qcut(df_q['xG_diff'], q=4,
                                   labels=['Q1\n(Away adv.)', 'Q2', 'Q3', 'Q4\n(Home adv.)'])
    wr = df_q.groupby('xG_quartile', observed=True)['Home_Win'].agg(['mean', 'count'])

    fig, ax = plt.subplots(figsize=(6, 5))
    hatches_q = ['...', '///', 'xxx', '+++']
    bars = ax.bar(range(len(wr)), wr['mean'] * 100,
                  color='white', edgecolor='black', linewidth=1)
    for bar, h in zip(bars, hatches_q):
        bar.set_hatch(h)
    for i, (rate, n) in enumerate(zip(wr['mean'], wr['count'])):
        ax.text(i, rate * 100 + 1.5, f'n={n}', ha='center', fontsize=9)

    ax.set_xticks(range(len(wr)))
    ax.set_xticklabels(wr.index, fontsize=10)
    ax.set_ylabel('Home win rate (%)', fontsize=11)
    ax.set_xlabel('xG difference quartile', fontsize=11)
    ax.set_title('Figure 10. Home win rate by xG difference quartile', fontsize=8)
    ax.set_ylim(0, 85)
    plt.tight_layout()
    plt.show()

    print('Table 3. Home win rate and match count by xG quartile')
    print(wr.rename(columns={'mean': 'Win rate', 'count': 'Matches'}).round(3).to_string())
# Out:
# Table 3. Home win rate and match count by xG quartile
#                  Win rate  Matches
# xG_quartile
# Q1\n(Away adv.)     0.066      407
# Q2                  0.260      407
# Q3                  0.563      407
# Q4\n(Home adv.)     0.843      407

# %% [markdown]
# ### Figure 11. Match count by tier difference value
#
# Number of matches for each integer value of diff_Tier (from -3 to +3). Positive values indicate the home team belongs to a higher FIFA tier.

# %%
if 'diff_Tier' in df.columns:
    counts = df['diff_Tier'].value_counts().sort_index()
    bar_hatches = ['///', '...', 'xxx', '+++', r'\\\ ', '---', '|||']

    fig, ax = plt.subplots(figsize=(8, 5))
    bars = ax.bar(range(len(counts)), counts.values,
                  color='white', edgecolor='black', linewidth=1)
    for bar, h in zip(bars, bar_hatches[:len(counts)]):
        bar.set_hatch(h)
    for i, n in enumerate(counts.values):
        ax.text(i, n + counts.max() * 0.02, f"n={n}", ha="center", fontsize=9)

    ax.set_xticks(range(len(counts)))
    ax.set_xticklabels([str(v) for v in counts.index], fontsize=10)
    ax.set_xlabel('Tier difference (Home − Away)', fontsize=11)
    ax.set_ylabel('Number of matches', fontsize=11)
    ax.set_title('Figure 11. Match count by tier difference value', fontsize=12)
    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/c9/88zz0bpj7wx6d38dghnlklqh0000gn/T/ipykernel_79077/2101759951.py:9: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values " ". Passing invalid values is deprecated since 3.4 and will become an error in 3.11.
#   bar.set_hatch(h)
